# %% [markdown]
# # Introduction to bokeh
#
# ## Top 5 fun and entertaining plots
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Next, we will take a look at five sample plots include many diverse examples of how bokeh can be used for awesome data visualizations.
#    0. **scatterplot**
#    1. **histogram** with pdf and cdf curves
#    2. graph with **interactive sliders** to set parameters
#    3. **visualization tools**: pan, zoom, hover, crosshairs, lasso select, box select, poly select, save, undo, redo, tap
#    4. **geographical map**
#
#
# This material is based largely upon the sample graphs shown here:
# http://bokeh.pydata.org/en/latest/docs/gallery.html

# %% [markdown]
# # Sample data for your amusement is available:

# %% [markdown]
# Bokeh comes preinstalled with various types of sample data: look in the site-packages folder found in your virtual environment folder...
#
# `<path_to_where_you_installed_miniconda>/miniconda3/envs/bokeh_tut/lib/python3.5/site-packages/bokeh/sampledata/`
#
# Bokeh provides ready access to some of the smaller datasets via import, as we will see.
#
# There are other much larger datasets available as well, that we will be using and will get later, using:
#
# `bokeh.sampledata.download()`

# %% [markdown]
# # Simple scatterplot
# ---
#
# <img src='./images/220px-Iris_versicolor_3.jpg' height='250' width='300' style="float:right">

# %%
# Let's start by importing some of the data

from bokeh.plotting import figure, show, output_notebook
from bokeh.sampledata.iris import flowers

# When flowers is imported, it comes in as a pandas DataFrame
# DataFrames have a function called sample, that will let us see a representative
#     sample of all the data... let's look at 10 rows.

print(type(flowers))
print(len(flowers))
flowers.sample(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 150
#      sepal_length  sepal_width  petal_length  petal_width     species
# 148           6.2          3.4           5.4          2.3   virginica
# 125           7.2          3.2           6.0          1.8   virginica
# 100           6.3          3.3           6.0          2.5   virginica
# 39            5.1          3.4           1.5          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 118           7.7          2.6           6.9          2.3   virginica
# 126           6.2          2.8           4.8          1.8   virginica
# 33            5.5          4.2           1.4          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 52            6.9          3.1           4.9          1.5  versicolor

# %%
# Next, we will prep some enrichments that we can apply to our flower data
# We want to map the species of iris to a color so we create a dict.

colormap = {'setosa': 'red',
            'versicolor': 'green',
            'virginica': 'blue'}

# Then we create a list of colors... one color for each row in the flowers DataFrame.
# Based on the species in the species column, we insert the appropriate color
# into our list.

colors = [colormap[x] for x in flowers['species']]

# To see the results of our work, let's look at a sampling of the colors list.

print(len(colors))
colors[::10]
# Out:
# 150
# ['red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'green',
#  'green',
#  'green',
#  'green',
#  'green',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue']

# %%
p = figure(title = "Iris Morphology")

p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Petal Width'

p.circle(flowers["petal_length"],      # x values
         flowers["petal_width"],       # y values
         color=colors, 
         fill_alpha=0.2, 
         size=10)
# Out:
# GlyphRenderer(id='758a25b9-780b-48a5-9cc1-f4f2b025a271', ...)

# %%
output_notebook()
show(p)

# http://bokeh.pydata.org/en/latest/docs/gallery/iris.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ae555c29-52aa-4499-ae96-3ae0be6211d9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76b07fa9-e1c3-4ba0-9f14-a26955845ea6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("76b07fa9-e1c3-4ba0-9f14-a26955845ea6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76b07fa9-e1c3-4ba0-9f14-a26955845ea6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid
type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"84a14c1d-eb82-4444-b02d-adf29ef7324f","subtype":"Figure","type":"Plot"}},"id":"62c83ce4-12be-448e-ba7f-215b95ba8b2e","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y","line_color","fill_color"],"data":{"fill_color":["red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","red","green","green"," ...

# %% [markdown]
# # Workflow
# ---

# %% [markdown]
# As we look at the remaining examples, and as you create your own, a generic, but useful workflow is listed below. Following a workflow such as this, helps you to focus on one task at a time and create robust and easy to understand scripts.
#
# 1. Import libraries
# 1. Generate a figure
# 1. Create or load data and enrichments
# 1. Generate glyphs
# 1. Add attributes, annotations, interactions
# 1. Create outputs
#
# **NOTES**:
#
# * You may not need some steps in the above workflow, especially for barebones charts.
# * Conversely, your charts may be very sophisticated and you may need to expand on the above workflow.
# * This is intended as a starting point.
# * Your mileage may vary (YMMV)!

# %% [markdown]
# # Histogram: with pdf and cdf curves
# ---

# %%
# IMPORTS ---------------------------------------

import numpy as np
import scipy.special

from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_notebook

# %%
# GENERATE FIGURE -----------------------------------------

h = figure(title="Normal Distribution (μ=0, σ=0.5)",
            tools="save",
            background_fill_color="whitesmoke")

# Notice this creates a figure() object

h
# Out:
# Figure(id='d561cc92-1ba0-4d94-acf8-9c9f496f8cfa', ...)

# %% [markdown]
# ```
# h?
# ```
#
# versus
#
# ```
# h??
# ```

# %%
h??

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

# set the midpoint and spread of the data
mu, sigma = 0, 0.5

# draw a 1000 random samples from a normal distribution 
measured = np.random.normal(mu, sigma, 1000)

# compute the histogram of a set of data.
#     hist is an array of the y-values of the histogram points
#     edges is an array of the 'sides' of the rectangles as 
#     defined across the x-axis
hist, edges = np.histogram(measured, density=True, bins=50)

# create an array of x-values: 1000 values between -2 and 2
x = np.linspace(-2, 2, 1000)

# calculate the points for a pdf and a cdf based on:
#     * mu
#     * sigma
#     * the values of x
pdf = 1/(sigma * np.sqrt(2*np.pi)) * np.exp(-(x-mu)**2 / (2*sigma**2))
cdf = (1+scipy.special.erf((x-mu)/np.sqrt(2*sigma**2)))/2

print('MEASURED: ', measured[:10])
print()
print('HIST: ', len(hist), hist[:10])
print()
print('EDGES: ', len(edges), edges[:10])
print()
print('-' * 60, end='\n\n')
print('PDF: ', pdf[:10])
print()
print('CDF: ', cdf[:10])
# Out:
# MEASURED:  [-0.17877429 -0.37133468  0.04950594 -0.66680592  0.74042919  0.16143088
#  -0.10899642  0.32055966 -0.08447807 -0.06383199]
#
# HIST:  50 [ 0.01507805  0.          0.          0.          0.01507805  0.01507805
#   0.03015609  0.01507805  0.01507805  0.        ]
#
# EDGES:  51 [-1.87491651 -1.80859491 -1.74227332 -1.67595172 -1.60963013 -1.54330853
#  -1.47698694 -1.41066534 -1.34434374 -1.27802215]
#
# ------------------------------------------------------------
#
# PDF:  [ 0.00026766  0.00027636  0.00028533  0.00029457  0.00030409  0.0003139
#   0.000324    0.00033441  0.00034513  0.00035617]
#
# CDF:  [  3.16712418e-05   3.27602929e-05   3.38847210e-05   3.50456008e-05
#    3.62440370e-05   3.74811655e-05   3.87581535e-05   4.00762007e-05
#    4.14365401e-05   4.28404387e-05]

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. In the code cell below, use `?` to explore the `quad()` function assocated with the figure `h`
# 1. What is the default fill_color?
# 1. What does the characteristic `alpha` do?
# 1. How does `alpha` contrast with `line_alpha`?

# %%
# Let's look into the quad() method of our figure:

# %%
# GENERATE GLYPHS -----------------------------------------

h.quad(top=hist,
       bottom=0,
       left=edges[:-1],
       right=edges[1:],
       fill_color='yellow', alpha=0.9, line_color="orange")
# Out:
# GlyphRenderer(id='24583ffb-0c74-4c98-9f10-2d298dc40e45', ...)

# %%
# GENERATE GLYPHS (cont.)-----------------------------------

h.line(x, pdf, line_color="black", line_width=3, alpha=0.7, legend="PDF")
h.line(x, cdf, line_color="red", line_width=2, alpha=0.7, legend="CDF")
# Out:
# GlyphRenderer(id='539ce078-2c6c-42ab-8ebb-7ebe33797b38', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

h.legend.location = "top_left"
h.xaxis.axis_label = 'x'
h.yaxis.axis_label = 'Pr(x)'

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(h)

# http://bokeh.pydata.org/en/latest/docs/gallery/histogram.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0dee4b14-89de-4846-afe6-03ee1ca3083a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2235d498-1b2e-4fd7-8bbc-d663184407be"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("2235d498-1b2e-4fd7-8bbc-d663184407be");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2235d498-1b2e-4fd7-8bbc-d663184407be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2235d498-1b2e-4fd7-8bbc-d663184407be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"95adf645-ecde-4a68-a914-94b6f49f5719":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d51302b4-0b1d-425c-8514-353909257601","type":"Line"},{"attributes":{"data_source":{"id":"a3dfa861-fa5d-4f0c-9cfb-158bc161c00b","type":"ColumnDataSource"},"glyph":{"id":"61369b1f-4958-4d3e-959e-024d99c1de8c","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d51302b4-0b1d-425c-8514-353909257601","type":"Line"},"selection_glyph":null},"id":"539ce078-2c6c-42ab-8ebb-7ebe33797b38","type":"GlyphRenderer"},{"attributes":{"background_fill_color":{"value":"whitesmoke"},"below":[{"id":"8a9eb1f2-772f-42d2-95d8-053f8388eb45","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"6e22cea8-7db1-4164-8cdf-2868c1fe0e19","type":"LinearAxis"}],"renderers":[{"id":"8a9eb1f2-772f-42d2-95d8-053f8388eb45","type":"LinearAxis"},{"id":"ae2ca47a-2e46-433a-96cc-b43ef0d7675e","type":"Grid"},{"id":"6e22cea8-7db1-4164-8cdf-2868c1fe0e19","type":"LinearAxis"},{"id":"c5f7e32a-765b-4732-862a-12907a8fbe13","type":"Grid"},{"id":"36bdf273-5e3e-4a6a-90a0-48b44ae1daf6","type":"GlyphRenderer"},{"id":"32f034a7-a6d1-4a5e-b81a-85eb557a5237","type":"GlyphRenderer"},{"id":"d538de16-13b5-4436-b750-48875e8fda1d","type":"GlyphRenderer"},{"id":"24583ffb-0c74-4c98-9f10-2d298dc40e45","type":"GlyphRenderer"},{"id":"bdd7155a-cc5b-4efd-8d2d-838375e5458a","type":"Legend"},{"id":"c44d6b6f-702b-4376-889e-f7fb5f2f81fc","type":"GlyphRenderer"},{"id":"539ce078-2c6c-42ab-8ebb-7ebe33797b38","type":"GlyphRenderer"}],"title":{"id":"ab09c2e3-7087-4092-a310-26ca9b96b261","type":"Title"},"tool_events":{"id":"5f68dcbe-9d59-4639-b69e-0e3f2026c3a1","type":"ToolEvents"},"toolbar":{"id":"5f7e0e30-53e4-49c4-ab55-8181e5bc4b1f","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"224b9b8a-3427-4db1-8013-19b44190d16b","type":"DataRange1d"},"y_mapper_type":"auto","y_range":{"id":"ebe600b2-bb2c-4b93-8a21-e2eb02268aff","type":"DataRange1d"}},"id":"d561cc92-1ba0-4d94-acf8-9c9f496f8cfa","subtype":"Figure","type":"Plot"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"bca13f90-295c-4a7e-83e3-26fd5d715fe8","type":"Quad"},{"attributes":{},"id":"efd090c7-195d-4fbb-a565-fd5649b1fee7","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["top","left","right"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"57465f27-7bef-4b48-9c17-8838d7a2a65b","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"d561cc92-1ba0-4d94-acf8-9c9f496f8cfa","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d7f6d5d-8a51-41b9-92e0-b00d3484adf9","type":"BasicTicker"}},"id":"c5f7e32a-765b-4732-862a-12907a8fbe13","type":"Grid"},{"attributes":{},"id":"79b4afab-01b6-4d81-b984-bb99e58d0f14","type":"BasicTicker"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"c37e277f-33ba-4f40-955f-b0894ef829be","type":"Quad"},{"attributes":{"callback":null,"column_names":["top","left","right"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"9d5d69df-d6eb-4344-89c3-f4127db51371","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.7},"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"61369b1f-4958-4d3e-959e-024d99c1de8c","type":"Line"},{"att ...

# %% [markdown]
# # Using interactive sliders
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np

from bokeh.layouts import row, widgetbox

from bokeh.models import CustomJS, Slider

from bokeh.plotting import figure, output_notebook, show, ColumnDataSource

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# # Try to identify the purpose of these two functions:
#
# 1. CustomJS
# 1. Slider

# %%
Slider?

# %%
# GENERATE FIGURE -----------------------------------------
plot = figure(y_range=(-10, 10), plot_width=400, plot_height=400)

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------
x = np.linspace(0, 10, 500)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# %%
# GENERATE GLYPHS -----------------------------------------
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)
# Out:
# GlyphRenderer(id='6176aa93-5696-42f5-9938-66380f37a36c', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------
# I am not a javascript guru.
# ... you are on your own in terms of making javascript


callback = CustomJS(args=dict(source=source), code="""
    var data = source.data;
    var A = amp.value;
    x = data['x']
    y = data['y']
    for (i = 0; i < x.length; i++) {
        y[i] = A*Math.sin(x[i]);
    }
    source.trigger('change');
    """)

amp_slider = Slider(start=0.1, end=10, value=1, step=.1,
                    title="Amplitude",
                    callback=callback)

callback.args["amp"] = amp_slider

layout = row(plot,
             widgetbox(amp_slider))

# %%
# CREATE OUTPUTS ------------------------------------------
output_notebook()
show(layout)

# http://bokeh.pydata.org/en/latest/docs/gallery/slider.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4048c9a3-b24c-4962-ba5b-58e5f0c8bc0c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1902d8c0-3f9f-4cc8-8c9e-d3eea2b8123c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1902d8c0-3f9f-4cc8-8c9e-d3eea2b8123c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1902d8c0-3f9f-4cc8-8c9e-d3eea2b8123c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1902d8c0-3f9f-4cc8-8c9e-d3eea2b8123c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"71795d7e-ed81-416e-ae5f-a73ee9d05943":{"roots":{"references":[{"attributes":{},"id":"6d7bceb0-ab1b-4e48-9817-344bb9eaf67b","type":"BasicTicker"},{"attributes":{"children":[{"id":"aa69556f-50f1-47c7-81ca-4f8aba50ecfa","type":"Slider"}]},"id":"445503f7-8245-4643-a618-f11663eb3a8f","type":"WidgetBox"},{"attributes":{"plot":{"id":"f400f5d3-ef8d-42b6-8624-e47e5946c7e8","subtype":"Figure","type":"Plot"}},"id":"cec26fc6-bf19-4cd4-a858-6ea69b057351","type":"SaveTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[500]},"y":{"__ndarray__":"...","dtype":"float64","shape":[500]}}},"id":"2bc88927-dc2b-4876-8378-16da14126487","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"f400f5d3-ef8d-42b6-8624-e47e5946c7e8","subtype":"Figure","type":"Plot"}},"id":"ee1be206-c5b7-4bbc-a4fc-84353d4aafcc","type":"HelpTool"},{"attributes":{"line_alpha":{"value":0.6},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"aaa56a4c-ca6c-4e0c-a663-01c0e4efaff0","type":"Line"},{"attributes":{"plot":null,"text":""},"id":"f5b332b3-bf10-4a17-bab1-ef3ee7a2ad90","type":"Title"},{"attributes":{"formatter":{"id":"b4c94d95-f0a0-4c61-9f1f-473b3d87b84d","type":"BasicTickFormatter"},"plot":{"id":"f400f5d3-ef8d-42b6-8624-e47e5946c7e8","subtype":"Figure","type":"Plot"},"ticker":{"id":"f17295a3-513a-4578-a321-6c77a09b2721","type":"BasicTicker"}},"id":"1a9b489f-7df5-4757-94e4-dc8dbab1f448","type":"LinearAxis"},{"attributes":{"plot":{"id":"f400f5d3-ef8d-42b6-8624-e47e5946c7e8","subtype":"Figure","type":"Plot"}},"id":"450e4a8e-31dd-4306-b6ea-c92222512201","type":"WheelZoomTool"},{"attributes":{},"id":"ecbd2a39-da26-40a7-a92d-b4964c23016f","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e33e66c2-fdb9-4579-94bf-5ec8f60f4eb7","type":"BoxAnnotation"},{"attributes":{"callback":{"id":"364194f3-8a00-42fe-b890-5ca9113c28a7","type":"CustomJS"},"end":10,"start":0.1,"title":"Amplitude","value":1},"id":"aa69556f-50f1-47c7-81ca-4f8aba50ecfa","type":"Slider"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc6b3cc0-7957-47d1-a6ab-d3ff2ce4c871","type":"Line"},{"attributes":{"args":{"amp":{"id":"aa69556f-50f1-47c7-81ca-4f8aba50ecfa","type":"Slider"},"source":{"id":"2bc88927-dc2b-4876-8378-16da14126487","type":"ColumnDataSource"}},"code":"\n    var data = source.data;\n    var A = amp.value;\n    x = data['x']\n    y = data['y']\n    for (i = 0; i < x.length; i++) {\n        y[i] = A*Math.sin(x[i]);\n    }\n    source.trigger('change');\n    "},"id":"364194f3-8a00-42fe-b890-5ca9113c28a7","type":"CustomJS"},{"attributes":{"overlay":{"id":"e33e66c2-fdb9-4579-94bf-5ec8f60f4eb7","type":"BoxAnnotation"},"plot":{"id":"f400f5d3-ef8d-42b6-8624-e47e5946c7e8","subtype":"Figure","type":"Plot"}},"id":"0468a5b1-cf46-4849-ace5-2e63db0ba2c8","type":"BoxZoomTool"},{"attributes":{},"id":"d3c9436c-d2a2-4928-ae3e-93624ad5ba69","type":"ToolEvents"},{"attributes":{},"id":"f17295a3-513a-4578-a321-6c77a09b2721","type":"BasicTicker"},{"attributes":{"below":[{"id":"3a42dbeb-9ed6-462a-94ee-47476193bb0a","type":"LinearAxis"}],"left":[{"id":"1a9b489f-7df5-4757-94e4-dc8dbab1f448","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"3a42dbeb-9ed6-462a-94ee-47476193bb0a","type":"LinearAxis"},{"id":"fe6b1938-ebbb-4955-8601-b7daa4c4a854","type":"Grid"},{"id":"1a9b489f-7df5-4757-94e4-dc8dbab1f448","type":"LinearAxis"},{"id":"d19a0bba-2b8c-4e5a-b825-4e1ce95edea2","type":"Grid"},{"id":"e33e66c2-fdb9-4579-94bf-5ec8f60f4eb7","type":"BoxAnnotation"},{"id":"6176aa93-5 ...

# %% [markdown]
# # Using visualization tools
# ---

# %%
# IMPORTS -------------------------------------------------

import numpy as np
from bokeh.plotting import figure, show, output_notebook

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

number = 4000
x = np.random.random(size=number) * 100     # random yields [0.0, 1.0) OR 0.0 <= x < 1.0
y = np.random.random(size=number) * 100

radii = np.random.random(size=number) * 1.5

# The following string formatting produces a hex number:
# %02x yields a zero padded hex number when you provide an integer
#     "#%02x" % (int(10)) would yield #0a
#     "#%02x%02x%02x" % (int(10), int(11), 150) would yield #0a0b96

colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS="crosshair,hover,pan,wheel_zoom,zoom_in,zoom_out,box_zoom,undo,redo,reset,tap,save,box_select,lasso_select"

p = figure(tools=TOOLS)

# GENERATE GLYPHS -----------------------------------------

p.scatter(x, y, radius=radii,
          fill_color=colors, fill_alpha=0.6,
          line_color=None)


# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(p)  # open a browser

# http://bokeh.pydata.org/en/latest/docs/gallery/color_scatter.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d203baa6-2be7-4d5d-b9f2-8c212430b775">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8071f4b9-35be-42a4-950d-f5cd05750629"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8071f4b9-35be-42a4-950d-f5cd05750629");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8071f4b9-35be-42a4-950d-f5cd05750629");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8071f4b9-35be-42a4-950d-f5cd05750629' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e4b34cbb-212d-4727-88f6-ea784cb35a6c":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"
","#4dd196","#8ab496","#4c1e96","#54ad96","#9dda96","#c37496","#7b2696","#945f96","#c58596","#f35d96","#c85596","#ee4696","#d03596","#982e96","#42a096","#e36a96","#4fd896","#6ad496","#d63696","#da9396","#b93b96","#c93b96","#682e96","#9baa96","#b53d96","#7bc796","#637d96","#bfd696","#50de96","#eda396","#869896","#8e5896","#f96e96","#73dd96","#5f4396","#bd5b96","#a77796","#ae7096","#828b96","#35b896","#aa2f96","#55e596","#e47596","#f09096","#818696","#5b5696","#8ae496","#99d996","#81e596","#425e96","#e87096","#7f9696","#e43d96","#85c096","# ...

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# Edit the code cell above to experiment with tool settings:
#
# 1. Add an **additional** `pan` tool to the TOOLS string and execute the code
#    * Consider the warning you get
#    * Look at the toolbar, anyway
#    * Remove the extra `pan` tool
# 1. Add the tool: `poly_select` to the TOOLS string and execute the code
# 1. Add the tool: `lasso_select` to the TOOLS string and execute the code

# %% [markdown]
# # Geographical map
# ---

# %%
# For larger datasets, we will need to download the data 

# The data will be stored in the following location:
# $home_directory/.bokeh/data

import bokeh
bokeh.sampledata.download()

# %%
# IMPORTS -------------------------------------------------

from bokeh.io import show
from bokeh.models import (
    ColumnDataSource,
    HoverTool,
    LogColorMapper
)

from bokeh.palettes import Viridis6 as palette
from bokeh.plotting import figure, output_notebook


from bokeh.sampledata.us_counties import data as counties
from bokeh.sampledata.unemployment import data as unemployment

# %%
# GENERATE FIGURE -----------------------------------------

TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"

texas = figure(title="Texas Unemployment, 2009", 
               tools=TOOLS, 
               x_axis_location=None,
               y_axis_location=None)

texas.grid.grid_line_color = None

# %%
# Let's understand the data:
# Looking at just the first 20 keys from the counties data, we see that they are 
# tuples with the first number equal to 48
# the second number is an odd number

print(sorted(counties.keys())[:20])       
print()

# Looking at just one set of data for the county 
# coded with tuple 48, 3, we see that the data is a state, some lats and longs and some names.

print(counties[(48,3)])
# Out:
# [(1, 1), (1, 3), (1, 5), (1, 7), (1, 9), (1, 11), (1, 13), (1, 15), (1, 17), (1, 19), (1, 21), (1, 23), (1, 25), (1, 27), (1, 29), (1, 31), (1, 33), (1, 35), (1, 37), (1, 39)]
#
# {'lats': [32.52315, 32.52309, 32.52308, 32.52307, 32.52304, 32.52311, 32.52328, 32.52293, 32.52298, 32.52305, 32.52333, 32.52334, 32.52325, 32.52316, 32.52319, 32.52324, 32.52223, 32.49588, 32.46638, 32.42405, 32.36164, 32.32856, 32.32684, 32.32369, 32.30704, 32.29004, 32.26794, 32.25861, 32.25666, 32.25145, 32.24007, 32.23176, 32.22406, 32.22033, 32.2129, 32.20843, 32.19757, 32.18818, 32.17704, 32.14543, 32.09943, 32.08746, 32.0868, 32.0868, 32.0868, 32.0868, 32.0868, 32.0868, 32.0868, 32.0868, 32.08681, 32.08682, 32.08683, 32.08685, 32.08685, 32.08685, 32.08686, 32.08686, 32.08687, 32.08691, 32.08692, 32.08693, 32.08694, 32.08694, 32.08695, 32.08696, 32.08698, 32.08699, 32.08699, 32.08699, 32.08709,
# Each key is a tuple, some of which match the tuples for the counties
# Each tuple is paired with an unemployment value.

for key, value in sorted(unemployment.items()):
    if key[0] == 48:
        print('{}: {}'.format(key, value))
# Out:
# (48, 1): 9.4
# (48, 3): 7.6
# (48, 5): 8.9
# (48, 7): 7.3
# (48, 9): 6.5
# (48, 11): 5.1
# (48, 13): 7.9
# (48, 15): 8.4
# (48, 17): 5.2
# (48, 19): 6.8
# (48, 21): 8.0
# (48, 23): 5.1
# (48, 25): 10.3
# (48, 27): 7.1
# (48, 29): 7.2
# (48, 31): 5.8
# (48, 33): 6.2
# (48, 35): 8.6
# (48, 37): 7.8
# (48, 39): 8.9
# (48, 41): 6.2
# (48, 43): 5.1
# (48, 45): 5.9
# (48, 47): 9.9
# (48, 49): 7.2
# (48, 51): 7.4
# (48, 53): 6.3
# (48, 55): 8.2
# (48, 57): 9.5
# (48, 59): 6.3
# (48, 61): 10.8
# (48, 63): 9.6
# (48, 65): 6.7
# (48, 67): 12.5
# (48, 69): 5.3
# (48, 71): 10.7
# (48, 73): 9.7
# (48, 75): 6.4
# (48, 77): 7.4
# (48, 79): 7.2
# (48, 81): 8.6
# (48, 83): 6.9
# (48, 85): 7.8
# (48, 87): 5.9
# (48, 89): 6.6
# (48, 91): 6.6
# (48, 93): 6.1
# (48, 95): 8.2
# (48, 97): 6.5
# (48, 99): 8.7
# (48, 101): 5.6
# (48, 103): 9.5
# (48, 105): 9.7
# (48, 107): 7.0
# (48, 109): 4.5
# (48, 111): 4.4
# (48, 113): 8.7
# (48, 115): 8.7
# (48, 117): 5.8
# (48, 119): 8.4
# (48, 121): 7.7
# (48, 123): 8.3
# (48, 125): 6.0
# (48, 127): 11.0
# (48, 129): 7.0
# (48, 131): 12.5
# (48, 133): 8.4
# (48, 135): 9.2
# (48, 137): 6.7
# (48, 139): 8.6
# (48, 141): 9.8
# (48, 143): 7.1
# (48, 145): 9.5
# (48, 147): 9.0
# (48, 149): 5.7
# (48, 151): 6.4
# (48, 153): 6.9
# (48, 155): 5.7
# (48, 157): 8.3
# (48, 159): 7.3
# (48, 161): 6.7
# (48, 163): 8.4
# (48, 165): 6.8
# (48, 167): 8.5
# (48, 169): 5.7
# (48, 171): 4.9
# (48, 173): 5.2
# (48, 175): 7.9
# (48, 177): 6.1
# (48, 179): 8.9
# (48, 181): 8.7
# (48, 183): 8.0
# (48, 185): 10.0
# (48, 187): 6.7
# (48, 189): 6.4
# (48, 191): 8.9
# (48, 193): 6.0
# (48, 195): 5.5
# (48, 197): 7.2
# (48, 199): 10.1
# (48, 201): 8.5
# (48, 203): 8.7
# (48, 205): 4.3
# (48, 207): 5.2
# (48, 209): 6.8
# (48, 211): 3.0
# (48, 213): 8.5
# (48, 215): 11.6
# (48, 217): 8.5
# (48, 219): 7.0
# (48, 221): 7.6
# (48, 223): 6.5
# (48, 225): 10.3
# (48, 227): 7.5
# (48, 229): 6.5
# (48, 231): 8.5
# (48, 233): 8.0
# (48, 235): 5.4
# (48, 237): 6.4
# (48, 239): 7.6
# (48, 241): 11.9
# (48, 243): 5.6
# (48, 245): 10.8
# (48, 247): 10.0
# (48, 249): 10.0
# (48, 251): 9.1
# (48, 253): 8.2
# (48, 255): 10.5
# (48, 257): 8.8
# (48, 259): 6.0
# (48, 261): 6.1
# (48, 263): 6.2
# (48, 265): 6.0
# (48, 267): 5.4
# (48, 269): 5.4
# (48, 271): 8.9
# (48, 273): 7.7
# (48, 275): 6.4
# (48, 277): 7.8
# (48, 279): 6.6
# (48, 281): 6.1
# (48, 283): 9.9
# (48, 285): 6.4
# (48, 287): 6.9
# (48, 289): 7.9
# (48, 291): 11.2
# (48, 293): 7.2
# (48, 295): 6.1
# (48, 297): 7.6
# (48, 299): 7.3
# (48, 301): 11.5
# (48, 303): 5.7
# (48, 305): 6.8
# (48, 307): 9.1
# (48, 309): 7.1
# (48, 311): 7.8
# (48, 313): 8.7
# (48, 315): 11.8
# (48, 317): 5.0
# (48, 319): 5.4
# (48, 321): 11.2
# (48, 323): 13.6
# (48, 325): 7.1
# (48, 327): 9.0
# (48, 329): 6.2
# (48, 331): 10.2
# (48, 333): 6.0
# (48, 335): 8.7
# (48, 337): 7.8
# (48, 339): 7.9
# (48, 341): 5.3
# (48, 343): 15.6
# (48, 345): 5.3
# (48, 347): 7.0
# (48, 349): 8.4
# (48, 351): 12.4
# (48, 353): 6.4
# (48, 355): 7.7
# (48, 357): 6.3
# (48, 359): 5.5
# (48, 361): 11.1
# (48, 363): 9.1
# (48, 365): 7.5
# (48, 367): 8.4
# (48, 369): 4.8
# (48, 371): 11.7
# (48, 373): 10.3
# (48, 375): 6.6
# (48, 377): 17.8
# (48, 379): 8.5
# (48, 381): 5.1
# (48, 383): 5.8
# (48, 385): 6.1
# (48, 387): 10.5
# (48, 389): 14.0
# (48, 391): 7.0
# (48, 393): 6.2
# (48, 395): 8.7
# (48, 397): 7.8
# (48, 399): 10.1
# (48, 401): 9.1
# (48, 403): 15.9
# (48, 405): 10.8
# (48, 407): 10.0
# (48, 409): 9.8
# (48, 411): 7.8
# (48, 413): 11.1
# (48, 415): 7.2
# (48, 417): 4.3
# (48, 419): 8.1
# (48, 421): 4.9
# (48, 423): 8.3
# (48, 425): 7.3
# (48, 427): 17.8
# (48, 429): 6.9
# (48, 431): 4.6
# (48, 433): 4.8
# (48, 435): 7.8
# (48, 437): 6.7
# (48, 439): 8.2
# (48, 441): 6.1
# (48, 443): 7.8
# (48, 445): 7.7
# (48, 447): 5.6
# (48, 449): 7.7
# (48, 451): 7.0
# (48, 453): 7.0
# (48, 455): 8.8
# (48, 457): 10.5
# (48, 459): 8.1
# (48, 461): 5.6
# (48, 463): 8.9
# (48, 465): 9.6
# (48, 467): 7.4
# (48, 469): 7.9
# (48, 471): 7.8
# (48, 473): 9.0
# (48, 475): 8.5
# (48, 477): 6.9
# (48, 479): 9.1
# (48, 481): 7.9
# (48, 483): 5.6
# (48, 485): 8.1
# (48, 487): 5.5
# (48, 489): 13.9
# (48, 491): 7.8
# (48, 493): 6.9
# (48, 495): 9.0
# (48, 497): 9.6
# (48, 499): 8.4
# (48, 501): 7.1
# (48, 503): 6.4
# (48, 505): 12.6
# (48, 507): 16.3

# %%
# CREATE OR LOAD DATA/ENRICHMENTS -------------------------

palette.reverse()

counties = {
    code: county for code, county in counties.items() if county["state"] == "tx"
}

county_xs = [county["lons"] for county in counties.values()]
county_ys = [county["lats"] for county in counties.values()]

county_names = [county['name'] for county in counties.values()]
county_rates = [unemployment[county_id] for county_id in counties]


# LogColorMapper will map numbers in a range [low, high] against a
# sequence of colors (i.e. a palette) on a natural logarithm scale.

color_mapper = LogColorMapper(palette=palette)

# ColumnDataSource() maps the names of columns to sequences or arrays,
# often using a dictionary OR DataFrame. Here we map all the values 
# of county_xs to a variable called x, etc.

source = ColumnDataSource(data=dict(
    x=county_xs,
    y=county_ys,
    name=county_names,
    rate=county_rates,
))

# %%
# GENERATE GLYPHS -----------------------------------------

# Here, we are referring to the 'x' and 'y' data found in the 
# ColumnDataSource we just created.
# Note that we use the string 'x' NOT x

texas.patches('x', 'y', source=source,
              fill_color={'field': 'rate', 'transform': color_mapper},
              fill_alpha=0.7, line_color="white", line_width=0.5)
# Out:
# GlyphRenderer(id='e63f1508-a3e6-40ea-83c3-c8a7727b11b3', ...)

# %%
# ADD ATTRIBUTES, ANNOTATIONS, INTERACTIONS ---------------

hover = texas.select_one(HoverTool)

hover.point_policy = "follow_mouse"

hover.tooltips = [("Name", "@name"),
                  ("Unemployment rate)", "@rate%"),
                  ("(Long, Lat)", "($x, $y)"),]

# %%
# CREATE OUTPUTS ------------------------------------------

output_notebook()
show(texas)

# http://bokeh.pydata.org/en/latest/docs/gallery/texas.html
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77bff7ab-3526-408b-a9e3-cc312c715819">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51138164-9910-4326-bc37-88280efd25d4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("51138164-9910-4326-bc37-88280efd25d4");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51138164-9910-4326-bc37-88280efd25d4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51138164-9910-4326-bc37-88280efd25d4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f29552aa-2dc3-4ca0-b121-5559bd469628":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"xs":{"field":"x"},"ys":{"field":"y"}},"id":"adc9d8d6-03fe-4a10-a893-84933e4f9d11","type":"Patches"},{"attributes":{"plot":{"id":"f1576bb5-d061-4c94-a54b-f99e073ed2b1","subtype":"Figure","type":"Plot"}},"id":"f24d8ba5-7564-485b-9711-67a570c24041","type":"PanTool"},{"attributes":{"callback":null},"id":"4e12bf4c-8b42-46c4-ab39-0cf6af03029f","type":"DataRange1d"},{"attributes":{},"id":"09432260-28f7-4157-926a-37ee96c88bca","type":"BasicTicker"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"f1576bb5-d061-4c94-a54b-f99e073ed2b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"09432260-28f7-4157-926a-37ee96c88bca","type":"BasicTicker"}},"id":"d2daa191-a44f-4f4f-a866-4d11f9aef787","type":"Grid"},{"attributes":{"callback":null},"id":"bc957039-e80b-43e8-9747-1c55003b6ff6","type":"DataRange1d"},{"attributes":{},"id":"ea647fa7-f053-4df4-ab71-8ecbce649306","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["rate","x","y","name"],"data":{"name":["Montague","Brewster","Eastland","Lee","Willacy","Cass","Hood","Tarrant","Anderson","Foard","Polk","Uvalde","Colorado","McCulloch","Rockwall","Crane","Jasper","Milam","Bowie","Hall","Kerr","Wheeler","Dickens","Hidalgo","Shackelford","Callahan","Fayette","Parker","Zapata","Coleman","Loving","Refugio","Bailey","Irion","Medina","Webb","Garza","Kendall","Schleicher","Delta","Hamilton","Nacogdoches","Burnet","Erath","Lampasas","Wood","Clay","Lipscomb","Stonewall","Armstrong","Hudspeth","Reagan","Tyler","Frio","Martin","San Jacinto","Cooke","Johnson","Moore","Brooks","Grimes","Knox","Wilson","Chambers","Hays","Starr","Angelina","Franklin","Orange","Tom Green","Comanche","McMullen","Real","Bell","Jefferson","Mitchell","Waller","Gray","King","Wilbarger","Dallas","Harrison","Sherman","Camp","Edwards","Nueces","Collingsworth","Leon","Terrell","Bastrop","Jackson","Presidio","Van Zandt","Glasscock","Kent","Rusk","Crosby","Hardeman","Newton","Brazos","Duval","Lavaca","Young","Carson","Hockley","Swisher","Austin","Floyd","Pecos","Upton","Galveston","Lynn","Robertson","Cottle","Karnes","Midland","Bosque","Hale","Lamb","Wharton","DeWitt","Henderson","Sterling","Calhoun","Fannin","Panola","Trinity","Coke","Llano","Reeves","Blanco","Hutchinson","Maverick","Washington","Gregg","Kaufman","San Saba","Deaf Smith","Haskell","Motley","Burleson","El Paso","Oldham","Wise","Childress","Limestone","Throckmorton","Archer","Howard","Randall","Walker","Freestone","Marion","San Augustine","Dallam","Jim Wells","Montgomery","Briscoe","Ector","Kleberg","Williamson","Castro","Hopkins","Somervell","Andrews","Fort Bend","Potter","Titus","Comal","McLennan","Runnels","Bee","Jeff Davis","Mills","Brazoria","Gonzales","Kimble","Wichita","Dimmit","Harris","Shelby","Cameron","Fisher","Nolan","Zavala","Collin","Lubbock","Taylor","Bandera","Jack","Menard","Val Verde","Gillespie","Kenedy","Scurry","Crockett","Hansford","Navarro","Caldwell","Donley","La Salle","Yoakum","Cochran","Hill","Sutton","Atascosa","Hunt","Parmer","Upshur","Gaines","Mason","Roberts","Coryell","Jones","Morris","Borden","Guadalupe","Lamar","Winkler","Denton","Hemphill","Stephens","Aransas","Falls","Palo Pinto","Travis","Concho","Live Oak","Red River","Bexar","Jim Hogg","Matagorda","Ward","Grayson","Kinney","San Patricio","Dawson","Hartley","Smith","Brown","Ellis","Ochiltree","Cherokee","Liberty","Terry","Baylor","Houston","Rains","Victoria","Goliad","Madison","Sabine","Culberson","Hardin"],"rate":[7.8,5.1,8.4,6.9,13.9,12.5,7.6,8.2,9.4,5.7,10.3,8.9,6.6,9.1,7.8,9.5,11.9,10.2,7.8,8.9,6.0,5.6,6.0,11.6,4.3,6.3,5.7,8.4,12.6,6.9,11.5,7.0,5.2,5.4,7.1,9.1,5.7,6.0,11.1,8.4,6.0,7.0,6.3,7.1,6.1,8.4,7.4,6.1,4.8,5.1,6.5,5.8,10.5,8.4,5.0,10.0,6.5,9.1,5.3,9.9,10.0,6.4,6.9,10.7,6.8,17.8,8.9,7. ...

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# 1. On the Internets, research the syntax for generating tool tips.

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [First Graph](./first_graph.ipynb) | [Table of Contents](./README.md) | [What Went Wrong](./what_went_wrong.ipynb) >>> |
