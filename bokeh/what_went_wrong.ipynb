# %% [markdown]
# # Introduction to bokeh
#
# ## Wait, what? Why doesn't that work?
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Sometimes, things just don't work out...

# %% [markdown]
# # Some functions don't have help docstrings builtin, yet.
#
# 1. Read the Manual
# 1. `google` for it
# 1. Post a question to `stackoverflow.com`
# 1. Publish an issue to the bokeh github account
# 1. Create a fix, yourself AND get your fifteen minutes of fame.

# %% [markdown]
# # So what happens if I execute certain cells multiple times?
#
# It depends...
#
# Sometimes doing your science requires multiple iterations and you might be tempted to tweak a cell and `show()` results, tweak a cell and `show()` the results, etc...
#
# Unless you reset the figure (i.e. create a blank slate) you may not get what you want.
#
# When you execute a cell that produces glyphs, bokeh will start to accumulate the glyphs until you call `show()` again. Which means you may have multiple overlapping glyphs.

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np
from random import choice

p = figure()

# %% [markdown]
# # Experience Points:
#
# 1. Run the following cell multiple times (i.e. five or six)
# 1. Once you have run it, then proceed to the following cell to see your graph.

# %%
color = choice(['red', 'green', 'blue', 'purple', 'black', 'orange', 'grey'])
x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = np.random.randint(1, 20, 7)

p.line(x_values, y_values, line_color=color)
# Out:
# GlyphRenderer(id='e57819a9-0e40-4c87-979a-527a430ccc82', ...)

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="79ebcc7b-d54a-43a1-94fa-d6b3e1d0a818">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a33c338c-ac56-4d78-b9d3-dc7e174f91e7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a33c338c-ac56-4d78-b9d3-dc7e174f91e7");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a33c338c-ac56-4d78-b9d3-dc7e174f91e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a33c338c-ac56-4d78-b9d3-dc7e174f91e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5159d395-df34-4e38-818a-82819fc67201":{"roots":{"references":[{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"afea5db1-4819-46e3-a618-fb32c7e07806","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[9,19,13,9,15,5,10]}},"id":"12b777b9-2704-4542-b50f-5b0783f36d81","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a68b2347-dec4-4bee-b284-480e8c9cb7bb","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab02da51-4cf8-4695-8d7d-323b8b92e53c","type":"Line"},{"attributes":{"formatter":{"id":"8f018771-290f-4abd-bcc9-f506dd04040f","type":"BasicTickFormatter"},"plot":{"id":"6af3ab3b-08fb-4535-a418-d1dd0c3023d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"3083590d-5f3a-4b76-9bdc-27238a4733a3","type":"BasicTicker"}},"id":"73c3eca8-02b4-401e-80c7-869d90a1e300","type":"LinearAxis"},{"attributes":{},"id":"345c872d-2f35-4dfa-a19b-4ff9f86856c1","type":"BasicTicker"},{"attributes":{},"id":"8f018771-290f-4abd-bcc9-f506dd04040f","type":"BasicTickFormatter"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"a40d8cd1-9d66-483c-a145-dbcf94657f96","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[4,12,3,14,15,15,19]}},"id":"98876e49-2601-49b7-bf65-461ec690b701","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6a63c55-288a-4b74-a458-0b2741761a6b","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[9,8,14,5,17,3,14]}},"id":"5e980ce2-3ce3-437a-80a5-64062853d307","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d48a374-87f1-42d5-bdfd-9b4d439dce29","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9429a8fa-61d2-48cc-ba8b-4d6c01dbc50e","type":"Line"},{"attributes":{"line_color":{"value":"orange"},"x":{"field":"x"},"y":{"field":"y"}},"id":"afbe19b0-3f3c-4098-8770-919fd1497c8c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b47e2aaa-ee03-4777-91a5-37e695d82717","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3274acda-0235-4cce-95bd-8980687762b8","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[11,10,19,14,5,7,10]}},"id":"12f5ad73-f664-4c07-a701-fcb4faebe4ea","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1966bc7-2a23-4b86-b630-748c74d744a5","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4e3cfd0-3c17-4179-aba2-043655717a18","type":"Line"},{"attributes":{"plot":{"id":"6af3ab3b-08fb-4535-a418-d1dd0c3023d0","subtype":"Figure","type":"Plot"}},"id":"784f1fa1-52e7-4f7e-8cd9-256a73cd1888","type":"PanTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"00220954-0984-46a3-b930-8a1d09173aba","type":"Line"},{"attributes":{"data_source":{"id":"12f5ad73-f664-4c07-a701-fcb4faebe4ea","type":"ColumnDataSource"},"glyph":{"id":"6cb7ca12-4902-413b-9d0d-041fb6655e6d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e614e753-1c0e-403e-acd8-efa7ba3b61f4","type":"Line"},"selection_glyph":null},"id":"59c73fba-f7ae-43e8-bd96-e8de7863d66d","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alph ...

# %% [markdown]
# # refresh running servers
#
# Yeah... this got wonky.
#
# Let me tell you what happened.
#
# Never figured out why

# %% [markdown]
# # running code for servers
#
# This took an inordinate amount of time to figure out.

# %% [markdown]
# # internets access required, sorta...
#
# During a previous rendition of this tutorial, we lost all internet access pretty early on and that impacted some attendees ability to complete some tasks: their systems looked for, if I recall correctly, certain javascript libraries on the internet...
#
# If you find you need to host your code on systems that are connected to the internet, you should plan on testing your systems...

# %% [markdown]
# # output_file() you're killing me
#
# Upon running `output_file()` once in the notebook, other examples reused that reference and output files... especially if I was doing iterative development OR testing.
#
# Potentiallly **OVERWRITING** what I had already produced.
#
# Also: when running `output_file()` in Chrome, it opened in my default browser: Safari.

# %%
from bokeh.plotting import output_file

output_file('myresults.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="09e3e17f-2dd9-41cb-8a75-d6c3ffe0219a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("09e3e17f-2dd9-41cb-8a75-d6c3ffe0219a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09e3e17f-2dd9-41cb-8a75-d6c3ffe0219a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09e3e17f-2dd9-41cb-8a75-d6c3ffe0219a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9281584d-7488-4b85-8bc1-50a663b79eae":{"roots":{"references":[{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"afea5db1-4819-46e3-a618-fb32c7e07806","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[9,19,13,9,15,5,10]}},"id":"12b777b9-2704-4542-b50f-5b0783f36d81","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a68b2347-dec4-4bee-b284-480e8c9cb7bb","type":"Line"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab02da51-4cf8-4695-8d7d-323b8b92e53c","type":"Line"},{"attributes":{"formatter":{"id":"8f018771-290f-4abd-bcc9-f506dd04040f","type":"BasicTickFormatter"},"plot":{"id":"6af3ab3b-08fb-4535-a418-d1dd0c3023d0","subtype":"Figure","type":"Plot"},"ticker":{"id":"3083590d-5f3a-4b76-9bdc-27238a4733a3","type":"BasicTicker"}},"id":"73c3eca8-02b4-401e-80c7-869d90a1e300","type":"LinearAxis"},{"attributes":{},"id":"345c872d-2f35-4dfa-a19b-4ff9f86856c1","type":"BasicTicker"},{"attributes":{},"id":"8f018771-290f-4abd-bcc9-f506dd04040f","type":"BasicTickFormatter"},{"attributes":{"x":{"field":"x"},"y":{"field":"y"}},"id":"a40d8cd1-9d66-483c-a145-dbcf94657f96","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[4,12,3,14,15,15,19]}},"id":"98876e49-2601-49b7-bf65-461ec690b701","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6a63c55-288a-4b74-a458-0b2741761a6b","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[9,8,14,5,17,3,14]}},"id":"5e980ce2-3ce3-437a-80a5-64062853d307","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d48a374-87f1-42d5-bdfd-9b4d439dce29","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9429a8fa-61d2-48cc-ba8b-4d6c01dbc50e","type":"Line"},{"attributes":{"line_color":{"value":"orange"},"x":{"field":"x"},"y":{"field":"y"}},"id":"afbe19b0-3f3c-4098-8770-919fd1497c8c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b47e2aaa-ee03-4777-91a5-37e695d82717","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3274acda-0235-4cce-95bd-8980687762b8","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[11,10,19,14,5,7,10]}},"id":"12f5ad73-f664-4c07-a701-fcb4faebe4ea","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b1966bc7-2a23-4b86-b630-748c74d744a5","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d4e3cfd0-3c17-4179-aba2-043655717a18","type":"Line"},{"attributes":{"plot":{"id":"6af3ab3b-08fb-4535-a418-d1dd0c3023d0","subtype":"Figure","type":"Plot"}},"id":"784f1fa1-52e7-4f7e-8cd9-256a73cd1888","type":"PanTool"},{"attributes":{"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"00220954-0984-46a3-b930-8a1d09173aba","type":"Line"},{"attributes":{"data_source":{"id":"12f5ad73-f664-4c07-a701-fcb4faebe4ea","type":"ColumnDataSource"},"glyph":{"id":"6cb7ca12-4902-413b-9d0d-041fb6655e6d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e614e753-1c0e-403e-acd8-efa7ba3b61f4","type":"Line"},"selection_glyph":null},"id":"59c73fba-f7ae-43e8-bd96-e8de7863d66d","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alph ...

# %%
# On my machine, when I create a new figure()
# and then attempt to show() the new figure...
# It ALSO attempts to write to the file myresults.html,
# overwriting my previous result.

h = figure()
show(h)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e0f8f16-8384-4a24-b345-d745154dfcef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6e0f8f16-8384-4a24-b345-d745154dfcef");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e0f8f16-8384-4a24-b345-d745154dfcef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e0f8f16-8384-4a24-b345-d745154dfcef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"97c2fea9-fb83-4a78-9e33-4ec18449fd3f":{"roots":{"references":[{"attributes":{},"id":"f30248ff-88ca-420f-9583-05430f3dfa1e","type":"ToolEvents"},{"attributes":{},"id":"9863246a-da0f-45ec-8e35-6f32f2e8099a","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"9863246a-da0f-45ec-8e35-6f32f2e8099a","type":"BasicTickFormatter"},"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b204fa8-7cbe-4b7e-88c1-d7577201a03a","type":"BasicTicker"}},"id":"839c780a-cbb1-41ee-9d5b-6332a417151d","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a355e88f-c6fe-40a7-b455-a2c05f82600d","type":"PanTool"},{"id":"353ba546-fc62-474b-8117-5f452f19257a","type":"WheelZoomTool"},{"id":"9efe7767-df47-4d9d-a9e3-640997f725c0","type":"BoxZoomTool"},{"id":"67850248-fd60-4299-811d-5680afa55c03","type":"SaveTool"},{"id":"508437d1-5297-4982-bf7c-a94829d65bee","type":"ResetTool"},{"id":"eb860b6a-9823-4d37-b89d-99cefa1faa08","type":"HelpTool"}]},"id":"05be43d5-4b23-4145-8667-f158f20f67c8","type":"Toolbar"},{"attributes":{"callback":null},"id":"273ba981-3b91-4e98-9cfd-8062a5a047e6","type":"DataRange1d"},{"attributes":{},"id":"41ab3e04-8e93-4efe-9d7b-c086c0135b08","type":"BasicTicker"},{"attributes":{"formatter":{"id":"69d6ea21-3ee2-4a9a-9719-23344adadc12","type":"BasicTickFormatter"},"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"},"ticker":{"id":"41ab3e04-8e93-4efe-9d7b-c086c0135b08","type":"BasicTicker"}},"id":"d8e523a8-e213-4190-976c-7f80212e8911","type":"LinearAxis"},{"attributes":{"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"}},"id":"a355e88f-c6fe-40a7-b455-a2c05f82600d","type":"PanTool"},{"attributes":{"overlay":{"id":"a1a47bc3-5aa4-4f5c-99b4-b656c0e219cb","type":"BoxAnnotation"},"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"}},"id":"9efe7767-df47-4d9d-a9e3-640997f725c0","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"}},"id":"67850248-fd60-4299-811d-5680afa55c03","type":"SaveTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a1a47bc3-5aa4-4f5c-99b4-b656c0e219cb","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"}},"id":"eb860b6a-9823-4d37-b89d-99cefa1faa08","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"},"ticker":{"id":"6b204fa8-7cbe-4b7e-88c1-d7577201a03a","type":"BasicTicker"}},"id":"f5c0f4e3-bf10-46f3-a400-96b9124108e1","type":"Grid"},{"attributes":{},"id":"6b204fa8-7cbe-4b7e-88c1-d7577201a03a","type":"BasicTicker"},{"attributes":{"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"}},"id":"508437d1-5297-4982-bf7c-a94829d65bee","type":"ResetTool"},{"attributes":{"callback":null},"id":"2b3146a5-2414-444e-8504-56b8296373bf","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"44b3925d-e743-4dd3-be82-4a80d566ba1a","type":"Title"},{"attributes":{"plot":{"id":"2de04ec5-7d73-4fe4-beaa-e4785e5fdb62","subtype":"Figure","type":"Plot"},"ticker":{"id":"41ab3e04-8e93-4efe-9d7b-c086c0135b08","type":"BasicTicker"}},"id":"c8a0d03e-9cbe-432d-ba42-68372c359a42","type":"Grid"},{"attributes":{"below":[{"id":"d8e523a8-e213-4190-976c-7f80212e8911","type":"LinearAxis"}],"left":[{"id":"839c780a-cbb1-41ee-9d5b-6332a417151d","type":"LinearAxis"}],"renderers":[{"id":"d8e523a8-e213-4190-976c-7f80212e8911","type":"LinearAxis"},{"id":"c8a0d03e-9cbe-432d-ba42-68372c359a42","t ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [Five Fun Examples](./five_fun.ipynb) |[Table of Contents](./README.md) | [Servers](./servers.ipynb) >>> |
