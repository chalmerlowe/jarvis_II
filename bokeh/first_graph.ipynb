# %% [markdown]
# # Introduction to bokeh
#
# ## Picture this, your first basic graph
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# # Creating a basic graph
# ---

# %%
from bokeh.plotting import figure, show, output_notebook

x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = [0.0, 1.0, 1.4, 1.7, 2.0, 2.2, 2.4]

p = figure()

p.line(x_values, y_values)

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4a50ba2d-c925-4e7f-b278-c7cf0fe8f9ef">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="67823da1-0b9f-43a1-90a4-e85b1634845d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("67823da1-0b9f-43a1-90a4-e85b1634845d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("67823da1-0b9f-43a1-90a4-e85b1634845d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '67823da1-0b9f-43a1-90a4-e85b1634845d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0ecb7905-8bcc-4154-80f4-957e2891a6a3":{"roots":{"references":[{"attributes":{"formatter":{"id":"fc037903-5c37-4271-98da-3a474a988a20","type":"BasicTickFormatter"},"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"459c8e10-2242-457b-89ba-0a2ef09d9d06","type":"BasicTicker"}},"id":"eccc97c3-3510-478c-aba5-895c779b3e95","type":"LinearAxis"},{"attributes":{"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"}},"id":"879a70a1-c77c-442d-9d5b-be70cefa2244","type":"PanTool"},{"attributes":{"below":[{"id":"108c01ce-4856-4663-8214-3c7527771b62","type":"LinearAxis"}],"left":[{"id":"eccc97c3-3510-478c-aba5-895c779b3e95","type":"LinearAxis"}],"renderers":[{"id":"108c01ce-4856-4663-8214-3c7527771b62","type":"LinearAxis"},{"id":"728957fe-e869-417f-a1b7-f17de1eb5fe5","type":"Grid"},{"id":"eccc97c3-3510-478c-aba5-895c779b3e95","type":"LinearAxis"},{"id":"a762875f-b2f2-4317-905e-ad437aed88a3","type":"Grid"},{"id":"b8703043-fc39-44a7-9b58-4d44989e34af","type":"BoxAnnotation"},{"id":"afc6c962-b3ea-4332-a452-41a00dfe75cc","type":"GlyphRenderer"}],"title":{"id":"da1316b7-3000-411f-a719-4517239f5c3a","type":"Title"},"tool_events":{"id":"754ec67e-868d-40c1-aa06-2adf2d34495c","type":"ToolEvents"},"toolbar":{"id":"b990ed33-7da3-40fb-a3b1-f5c854bebd7f","type":"Toolbar"},"x_range":{"id":"00b2cfd0-9c80-41f0-93f9-d34f63b19647","type":"DataRange1d"},"y_range":{"id":"f0bdf76d-2a3f-4443-9fbb-4b30286b46c0","type":"DataRange1d"}},"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"},{"attributes":{"plot":null,"text":""},"id":"da1316b7-3000-411f-a719-4517239f5c3a","type":"Title"},{"attributes":{"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a55c0742-45b5-4bd1-9b0b-9f998654085f","type":"BasicTicker"}},"id":"728957fe-e869-417f-a1b7-f17de1eb5fe5","type":"Grid"},{"attributes":{"callback":null},"id":"f0bdf76d-2a3f-4443-9fbb-4b30286b46c0","type":"DataRange1d"},{"attributes":{},"id":"35124307-3244-446c-9a9c-f7c955806f28","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b8703043-fc39-44a7-9b58-4d44989e34af","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"}},"id":"eb113398-c1d7-44dc-8507-cb1939dc845f","type":"ResetTool"},{"attributes":{},"id":"a55c0742-45b5-4bd1-9b0b-9f998654085f","type":"BasicTicker"},{"attributes":{"callback":null},"id":"00b2cfd0-9c80-41f0-93f9-d34f63b19647","type":"DataRange1d"},{"attributes":{"overlay":{"id":"b8703043-fc39-44a7-9b58-4d44989e34af","type":"BoxAnnotation"},"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"}},"id":"1107c833-22fa-4f14-adc2-b5908e6311fb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"}},"id":"180998f7-390e-4b89-bd28-f5ab4e0fb511","type":"WheelZoomTool"},{"attributes":{},"id":"fc037903-5c37-4271-98da-3a474a988a20","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"35124307-3244-446c-9a9c-f7c955806f28","type":"BasicTickFormatter"},"plot":{"id":"b96bd945-a39a-48fa-a02d-0a5ced6125d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"a55c0742-45b5-4bd1-9b0b-9f998654085f","type":"BasicTicker"}},"id":"108c01ce-4856-4663-8214-3c7527771b62","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d59997d2-4283-4c0e-a4bb-4ef5533084d2","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"879a70a1-c77c-442d-9d5b-be70cefa2244","type":"PanTool"},{" ...

# %% [markdown]
# # Get an error related to numpy?
# ## Are you on Windows?
#
# This [comment thread](https://github.com/ContinuumIO/anaconda-issues/issues/883), albeit related to scipy, may help.

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, try the following experiments:
#
# 1. Add an additional number to `x_values` and to `y_values` and execute the cell (press `Ctrl+Enter`)
# 1. Swap the `x_values` and `y_values` (i.e. change `p.line(...)` to `p.line(y_values, x_values)` and execute the cell
# 1. Add an additional value to the `x_values`, but leave the `y_values` alone, so that the number of elements is no longer the same, and execute the cell

# %% [markdown]
# # Getting help
# ---

# %% [markdown]
# ```python
# object?
# ```
#
# For example:
#
# ```python
# p?
# ```

# %%
p?

# %% [markdown]
# # Don't know what functions are available?
# ---

# %% [markdown]
# `p.<tab-complete>`

# %%
p.

# %% [markdown]
# # Want insight into what a _particular_ function can do?
# ---

# %% [markdown]
# `p.line?`

# %%
p.line?

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, use IPython help to read about the `p.line` method:
#
# 1. **DON'T FRET** if some of it feels like gibberish OR certain words or phrases are unclear.
#
# 1. This exercise is more about familiarizing you with what is available. Plus, many of these are found associated with every type of glyph, so you will see them over and over again and your familiarity will grow over time.
#
# 1. **NOTE:** I am not an expert on all of the parameters associated with the various glyphs, so don't fret if there seems to be a lot to learn.

# %% [markdown]
# # Let's do it again, but moar!
# ---
#
# ## with Circles
# ## with Dashes
# ## with Legends

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

moar = figure()

x = np.linspace(0.1, 5, 100)               # figures can handle numpy arrays
y = range(0, 200, 2)                       # and ranges()

# Let's use circular markers and a dotted and dashed line
# AND 
# add a legend with unique entries for each line

moar.circle(x, np.cumsum(x),
            legend="y=cumsum(y)")

moar.line(x, y, 
          legend="y=range(0, 200, 2)",
          line_color="#663399", line_dash="dotdash")

# And add a legend created from the legend attributes of each item

moar.legend.location = "top_left"

output_notebook()
show(moar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c5c33c9c-a0a7-4709-9c80-de12b3a5f265">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5b1bfa7e-dfc0-4714-9c07-654a6bf9a5bb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("5b1bfa7e-dfc0-4714-9c07-654a6bf9a5bb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b1bfa7e-dfc0-4714-9c07-654a6bf9a5bb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b1bfa7e-dfc0-4714-9c07-654a6bf9a5bb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"69173d39-2c36-4080-8874-246bb4f45888":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"85d8be19-aed3-4de5-9e91-186f9cee650b","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"}},"id":"4f400812-6856-49d1-9dcb-3740ed702890","type":"PanTool"},{"attributes":{"callback":null},"id":"64a2dde2-b1f1-4d19-8878-65bf04cddc8f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"0ca4771e-e2e8-45f7-a701-2972f57f1ba9","type":"BasicTickFormatter"},"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"},"ticker":{"id":"33fa21bb-9807-4f0b-8827-064a11a4cabe","type":"BasicTicker"}},"id":"1195c558-a33d-49b5-9c64-2e4587616d98","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"2ba6cc34-ec8e-4e36-a626-3ecd360ed807","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"d06e29b4-aa02-43a0-aca5-f91d3fb7653e","type":"BasicTickFormatter"},"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f24b0c6-d0cc-44f7-87cb-c0092e5a4a4c","type":"BasicTicker"}},"id":"46c54d55-3dde-4c60-9b1a-bcc4a60beb65","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4f400812-6856-49d1-9dcb-3740ed702890","type":"PanTool"},{"id":"f1137fea-725b-4f13-9116-840ac91860a2","type":"WheelZoomTool"},{"id":"c2b7172e-7b95-4222-a078-3621c411080d","type":"BoxZoomTool"},{"id":"e96be031-c2f1-4516-baa5-6d9db69611c0","type":"SaveTool"},{"id":"72971a58-1051-41c4-a8ea-bbdbc8da50ae","type":"ResetTool"},{"id":"64a2226b-e535-4db7-9254-132f17b4995d","type":"HelpTool"}]},"id":"50801ca4-7d08-4edc-a3bb-d9d42670172e","type":"Toolbar"},{"attributes":{"label":{"value":"y=range(0, 200, 2)"},"renderers":[{"id":"546939bd-5b28-4bf1-916a-87ade9c71906","type":"GlyphRenderer"}]},"id":"7972cdbc-aa16-4c63-82a2-6bed03e7579d","type":"LegendItem"},{"attributes":{"items":[{"id":"62f4a0c1-8d9a-449d-8766-291a2ed5e5b0","type":"LegendItem"},{"id":"7972cdbc-aa16-4c63-82a2-6bed03e7579d","type":"LegendItem"}],"location":"top_left","plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"}},"id":"ff94c369-473b-4fb6-bc1a-ea2801597c83","type":"Legend"},{"attributes":{"overlay":{"id":"85d8be19-aed3-4de5-9e91-186f9cee650b","type":"BoxAnnotation"},"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"}},"id":"c2b7172e-7b95-4222-a078-3621c411080d","type":"BoxZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3605e4c5-dbfa-45e1-9317-11c3aa6f05ec","type":"Circle"},{"attributes":{},"id":"33fa21bb-9807-4f0b-8827-064a11a4cabe","type":"BasicTicker"},{"attributes":{"label":{"value":"y=cumsum(y)"},"renderers":[{"id":"96c38b41-24ed-4a2f-af8e-e8f4015911df","type":"GlyphRenderer"}]},"id":"62f4a0c1-8d9a-449d-8766-291a2ed5e5b0","type":"LegendItem"},{"attributes":{"plot":null,"text":""},"id":"66e073aa-7849-449c-b04e-c7ed4e07b20b","type":"Title"},{"attributes":{"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"}},"id":"72971a58-1051-41c4-a8ea-bbdbc8da50ae","type":"ResetTool"},{"attributes":{"plot":{"id":"ddd826e3-c1d8-4f0f-b86a-7230a0f08801","subtype":"Figure","type":"Plot"},"ticker":{"id":"33fa21bb-9807-4f0b-8827-064a11a4cabe","type":"BasicTicker"}},"id":"94528419-1b34-4ba1-96fe-5486b50c8e7b","type":"Grid"},{"attributes": ...

# %% [markdown]
# # How to learn more, in these notebooks
# ---

# %% [markdown]
# 1. Select the cell in the notebook that contains something you want to learn more about
# 1. Click the `Insert cell below` button (the `plus` sign) on the Jupyter toolbar to make an empty cell
# <img src='./images/jupyter_toolbar.png' width='300' style="float:center"><br>
# 1. Inspect the variables and methods/functions
#    * `print()` the variable (or a subset of the variable)
#    * Use the `type()` function to figure out what type of object you have
#    * Use the question mark help functionality (`object?`) to learn more about the object
#    * Tweak something, see what happens.

# %%
# Out:
# numpy.ndarray

# %% [markdown]
# # Moarest! adding multiple features to a basic graph
# ---

# %% [markdown]
# ## Colors
#
# Bokeh has rich support for colors using the most common color schemas.
#
# * any of the 147 named CSS colors, e.g `green`, `indigo`, `purple`
# * hex values: Red, Green, Blue (optional Alpha) >>> RGB(A) e.g., `#FF0000`, `#44444444`
# * a 3-tuple of integers (R, G, B) between 0 and 255
# * a 4-tuple of (R, G, B, A) where R, G, B are integers between 0 and 255 and A is a floating point value between 0 and 1
#
# ## What colors and color names?
# [https://en.wikipedia.org/wiki/Web_colors](https://en.wikipedia.org/wiki/Web_colors)

# %%
from bokeh.plotting import figure, show, output_file, output_notebook
import numpy as np

x = np.linspace(0.1, 5, 100)
y = x

# Add a title
# Define the type of y-axis
# Set the range of values for the y-axis

p = figure(title="log axis example", 
           y_axis_type="log", y_range=(0.001, 10**22))

# %%
# Set the fill color for our circles to None

p.circle(x, y**2, legend="y=x**2", 
         fill_color=None, 
         line_color="blueviolet", size=5)
# Out:
# GlyphRenderer(id='c552efa6-25bb-41c9-aa27-fe692bce5f2d', ...)

# %%
# Create a line
# Set the line width to 2

p.line(x, 10**y, legend="y=10^x", line_color="darkred", 
       line_width=2)
# Out:
# GlyphRenderer(id='1c379efe-e495-4fc9-8942-9caecfcc85ea', ...)

# %%
# Add a line composed of squares
# Use hex this time to color the line

p.square(x, 10**(x**2), legend="y=10^(x^2)",
       line_color="#663399", 
       line_dash="solid", line_width=2)
# Out:
# GlyphRenderer(id='e534ced8-f2af-4900-a9db-7731bfbc4a59', ...)

# %%
# Move the legend location
# Change the legend font

p.legend.location = "center_left"
p.legend.label_text_font='times'

# Change characteristics of the title text (color, font, font-style)
# Using RGB tuple this time

p.title.text_font_size = '16pt'
p.title.text_color = (125, 125, 125)
p.title.text_font = "courier"
p.title.text_font_style = "bold"

# Set the background color

p.background_fill_color = "whitesmoke"

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9cff12e0-435a-4870-9716-4c3a00f5ea3d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="57e976d6-be20-4830-aeec-5093a5b8c3e2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("57e976d6-be20-4830-aeec-5093a5b8c3e2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("57e976d6-be20-4830-aeec-5093a5b8c3e2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '57e976d6-be20-4830-aeec-5093a5b8c3e2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"036f0883-9d3b-425f-bd8e-609dc9b3846a":{"roots":{"references":[{"attributes":{"formatter":{"id":"e26f9317-fb90-461e-90ed-fbc88ff309e1","type":"LogTickFormatter"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"},"ticker":{"id":"aa1a1a33-9440-49f9-b4a3-d801d7786bc2","type":"LogTicker"}},"id":"d386378f-0c0b-4b76-8b7d-b29d680b02b2","type":"LogAxis"},{"attributes":{"fill_color":{"value":null},"line_color":{"value":"blueviolet"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cbf2679f-fc7f-40c0-9da1-3da76e9fdefe","type":"Circle"},{"attributes":{"label":{"value":"y=10^x"},"renderers":[{"id":"1c379efe-e495-4fc9-8942-9caecfcc85ea","type":"GlyphRenderer"}]},"id":"db573e0b-0e72-4c19-a1dc-32e0eee93fa1","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"52cc7fcc-98c6-447b-bda1-daf3cf2167ca","type":"PanTool"},{"id":"8e7debfe-6aea-41fa-8b33-0f2530984198","type":"WheelZoomTool"},{"id":"a2ad190d-c05b-4a64-b911-698bc02dda30","type":"BoxZoomTool"},{"id":"2f9258bf-cc38-4e7b-9007-5900fb019d48","type":"SaveTool"},{"id":"e2c3f920-c3f7-40c8-9b95-2316748aaabc","type":"ResetTool"},{"id":"d7802ea5-e2fe-426b-bfe1-bd07a54d7e61","type":"HelpTool"}]},"id":"439dddcf-de64-4489-b349-e5e9339d00b4","type":"Toolbar"},{"attributes":{},"id":"1226920b-910b-408e-9352-4e5f8a7e9dd1","type":"ToolEvents"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#663399"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"16f0067d-f4a5-4a60-98dc-fa9d4da5c24b","type":"Square"},{"attributes":{"label":{"value":"y=10^(x^2)"},"renderers":[{"id":"e534ced8-f2af-4900-a9db-7731bfbc4a59","type":"GlyphRenderer"}]},"id":"98d05c2c-4cb3-45ea-b704-bf7064e654ff","type":"LegendItem"},{"attributes":{"overlay":{"id":"98fa6771-be53-4460-8347-ea1606d19951","type":"BoxAnnotation"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"}},"id":"a2ad190d-c05b-4a64-b911-698bc02dda30","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"log axis example","text_color":{"value":"rgb(125, 125, 125)"},"text_font":"courier","text_font_size":{"value":"16pt"}},"id":"91cd9d86-a2f6-49ad-a029-1d61f0853b14","type":"Title"},{"attributes":{"ticker":null},"id":"e26f9317-fb90-461e-90ed-fbc88ff309e1","type":"LogTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"42fe8916-a773-455e-98da-70d8cf53aec1","type":"Square"},{"attributes":{"formatter":{"id":"0b9e8287-dda0-4ab4-8549-237962c8ec87","type":"BasicTickFormatter"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"},"ticker":{"id":"07baa6ec-b551-4a6e-8614-4e83fe8824a5","type":"BasicTicker"}},"id":"3ac6d873-d401-45ee-9941-a627c9f9e984","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d41534b-353e-4774-a6f0-c3c9e1bc88f6","type":"Circle"},{"attributes":{},"id":"07baa6ec-b551-4a6e-8614-4e83fe8824a5","type":"BasicTicker"},{"attributes":{"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"}},"id":"d7802ea5-e2fe-426b-bfe1-bd07a54d7e61","type":"HelpTool"},{"attributes":{"items":[{"id":"12336e4d-97d0-4f33-a2aa-99c38cdc9668","type":"LegendItem"},{"id":"db573e0b-0e72-4c19-a1dc-32e0eee93fa1","type":"LegendItem"},{"id":"98d05c2c-4cb3-45ea-b704-bf7064e654ff","type":"LegendItem"}],"label_text_font":"times","location":"center_left","plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"}},"id":"ffa18853-2383-40f3-a93c-d5856d0ca6a2","type":"Legend"},{"attributes":{"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","s ...

# %% [markdown]
# # Color Palettes
# ---

# %% [markdown]
# http://bokeh.pydata.org/en/latest/docs/reference/palettes.html
#
# <img src='./images/purples.png' height='250' width='300' style="float:right">

# %%
from bokeh.palettes import Purples

# Internally, palettes such as Purples are stored as dictionaries:

# Key: integer indicating how many colors are in a sub palette
# Value: list of strings indicating the actual color values 

print(Purples[3], Purples[5], sep='\n', end='\n\n')

line_color = Purples[5][1]      # '#756bb1'

print("line_color:", line_color)
# Out:
# ['#756bb1', '#bcbddc', '#efedf5']
# ['#54278f', '#756bb1', '#9e9ac8', '#cbc9e2', '#f2f0f7']
#
# line_color: #756bb1

# %%
# Let's add a new line to the figure
# This one will use a dot-dash appearance and
# the color we chose above, from the Palette

p.line(x, np.sqrt(x) * 100, 
       legend="y=sqrt(x)", 
       line_color=line_color, 
       line_dash="dotdash", 
       line_width=3)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="59fc5665-bea5-4492-afcb-d94e3e4a817b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("59fc5665-bea5-4492-afcb-d94e3e4a817b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("59fc5665-bea5-4492-afcb-d94e3e4a817b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '59fc5665-bea5-4492-afcb-d94e3e4a817b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"913597a6-d488-4092-aaab-9297253b7bb8":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[2,4,6,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"69525adb-28a6-4d55-812e-814e008761f5","type":"Line"},{"attributes":{"formatter":{"id":"e26f9317-fb90-461e-90ed-fbc88ff309e1","type":"LogTickFormatter"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"},"ticker":{"id":"aa1a1a33-9440-49f9-b4a3-d801d7786bc2","type":"LogTicker"}},"id":"d386378f-0c0b-4b76-8b7d-b29d680b02b2","type":"LogAxis"},{"attributes":{"fill_color":{"value":null},"line_color":{"value":"blueviolet"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"cbf2679f-fc7f-40c0-9da1-3da76e9fdefe","type":"Circle"},{"attributes":{"label":{"value":"y=10^x"},"renderers":[{"id":"1c379efe-e495-4fc9-8942-9caecfcc85ea","type":"GlyphRenderer"}]},"id":"db573e0b-0e72-4c19-a1dc-32e0eee93fa1","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"42fe8916-a773-455e-98da-70d8cf53aec1","type":"Square"},{"attributes":{},"id":"1226920b-910b-408e-9352-4e5f8a7e9dd1","type":"ToolEvents"},{"attributes":{"label":{"value":"y=sqrt(x)"},"renderers":[{"id":"82d3f374-8dd5-4377-b154-ac634d20f7a1","type":"GlyphRenderer"}]},"id":"65e11932-efd0-41ef-bded-7922142f48b2","type":"LegendItem"},{"attributes":{},"id":"0b9e8287-dda0-4ab4-8549-237962c8ec87","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"y=10^(x^2)"},"renderers":[{"id":"e534ced8-f2af-4900-a9db-7731bfbc4a59","type":"GlyphRenderer"}]},"id":"98d05c2c-4cb3-45ea-b704-bf7064e654ff","type":"LegendItem"},{"attributes":{"overlay":{"id":"98fa6771-be53-4460-8347-ea1606d19951","type":"BoxAnnotation"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"}},"id":"a2ad190d-c05b-4a64-b911-698bc02dda30","type":"BoxZoomTool"},{"attributes":{"plot":null,"text":"log axis example","text_color":{"value":"rgb(125, 125, 125)"},"text_font":"courier","text_font_size":{"value":"16pt"}},"id":"91cd9d86-a2f6-49ad-a029-1d61f0853b14","type":"Title"},{"attributes":{"ticker":null},"id":"e26f9317-fb90-461e-90ed-fbc88ff309e1","type":"LogTickFormatter"},{"attributes":{"line_color":{"value":"#756bb1"},"line_dash":[2,4,6,4],"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"a8995a56-55e7-42cb-a688-c24cf7a829c5","type":"Line"},{"attributes":{"formatter":{"id":"0b9e8287-dda0-4ab4-8549-237962c8ec87","type":"BasicTickFormatter"},"plot":{"id":"09b104de-ea5c-49e6-bd1f-1964de262f8e","subtype":"Figure","type":"Plot"},"ticker":{"id":"07baa6ec-b551-4a6e-8614-4e83fe8824a5","type":"BasicTicker"}},"id":"3ac6d873-d401-45ee-9941-a627c9f9e984","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"1d41534b-353e-4774-a6f0-c3c9e1bc88f6","type":"Circle"},{"attributes":{},"id":"07baa6ec-b551-4a6e-8614-4e83fe8824a5","type":"BasicTicker"},{"attributes":{"line_color":{"value":"darkred"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"51539521-a344-4194-9268-c09c37d40443","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"52cc7fcc-98c6-447b-bda1-daf3cf2167ca","type":"PanTool"},{"id":"8e7debfe-6aea-41fa-8b33-0f2530984198","type":"WheelZoomTool"},{"id":"a2ad190d-c05b-4a64-b911-698bc02dda30","type":"BoxZoomTool"},{"id":"2f9258bf-cc38-4e7b-9007-5900fb019d48","type":"SaveTool"},{"id":"e2c3f920-c3f7-40c8-9b95-2316748aaabc","type":"ResetTool"},{"id":"d7802ea5-e2fe-426b-bfe1-bd07a54d7e61","type":"HelpTool"}]},"id":"439dddcf-de64-4489-b349-e5e9339d00b4","type":"Toolbar" ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [History](./history.ipynb) | [Table of Contents](./README.md) | [Five Fun Examples](./five_fun.ipynb) >>> |
