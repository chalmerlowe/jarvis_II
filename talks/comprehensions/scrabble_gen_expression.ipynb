# %%
with open('1138090f.txt') as fin:
    
    x_words = (word.strip() for word in fin if 'x' in word)
    print('This is a generator: ', x_words, '\n')
    
    for item in x_words:
        print(item)
# Out:
# This is a generator:  <generator object <genexpr> at 0x1066f4a98>
#
# abaxial
# abaxile
# aboideaux
# aboiteaux
# acetoxyl
# acetoxyls
# adaxial
# addax
# addaxes
# adieux
# admix
# admixed
# admixes
# admixing
# admixt
# admixture
# admixtures
# adnexa
# adnexal
# affix
# affixal
# affixed
# affixer
# affixers
# affixes
# affixial
# affixing
# afflux
# affluxes
# aftertax
# alexia
# alexias
# alexin
# alexine
# alexines
# alexins
# alkoxy
# alloxan
# alloxans
# ambidextrous
# ambidextrously
# amphioxi
# anatoxin
# anatoxins
# annex
# annexation
# annexations
# annexe
# annexed
# annexes
# annexing
# anorexia
# anorexias
# anorexies
# anorexy
# anoxemia
# anoxemias
# anoxemic
# anoxia
# anoxias
# anoxic
# antefix
# antefixa
# antefixes
# anthelix
# anthrax
# antiannexation
# antiboxing
# anticlimax
# anticlimaxes
# antihomosexual
# antisexist
# antisexual
# antitax
# antitoxin
# anxieties
# anxiety
# anxious
# anxiously
# apex
# apexes
# apomixes
# apomixis
# apoplexies
# apoplexy
# ...
