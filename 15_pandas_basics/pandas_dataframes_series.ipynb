# %% [markdown]
# # Welcome to the Dark Art of Coding:
# ## Introduction to Python
# pandas: Series & DataFrames
#
# <img src='../images/dark_art_logo.600px.png' width='300' style="float:right">

# %% [markdown]
# # Objectives
# ---

# %% [markdown]
# In this session, students should expect to:
#
# * understand the purpose and application of pandas to data analysis problems
# * understand how to create and use a Series
# * understand how to create and use a DataFrame
# * explore various simple examples of pandas usage

# %% [markdown]
# # `pandas` basics
# ---

# %% [markdown]
# `pandas` is one of the premier data analysis libraries in the Python ecosystem. It offers high-performance, easy-to-use data structures and data analysis tools enabling you to carry out your entire data analysis workflow.
#
# `pandas` is used for:
#
# * data analysis/science
# * financial analysis
# * data manipulation
# * data cleansing
# * data transformation

# %% [markdown]
# `pandas` has tools to read and write data to and from multiple data formats.
#
# It also includes tools that simplify:
#
# * grouping data
# * applying transformations to columns, rows and individual cells
# * working with dates and times

# %% [markdown]
# # List vs. Dict vs. Series vs. DataFrame
# ---

# %% [markdown]
# ## list
# ```python
# LIST:
# mylist = ['A', 'B', 'C']
# ```
#
# **indexable**:
#
# `mylist[0]` by integer
#
# **sliceable**:
#
# `mylist[0:2]` by integer

# %% [markdown]
# ## dict
# ```
# DICTIONARY:
# mydict = {'alpha': 1,
#           'beta': 2,
#           'gamma': 2}
# ```
#
# **indexable**:
#
# `mydict['alpha']` by key

# %% [markdown]
# ## Series
# ```
# myseries = Series(['bruce', 'selina', 'kara', 'clark])
#           column
# rows
# 0         'bruce'
# 1         'selina'
# 2         'kara'
# 'three'   'clark'
# ```
#
# **indexable**:
#
# `myseries[0]` by integer
#
# `myseries['three']` by row name
#
# **sliceable**:
#
# `myseries[0:3]`

# %% [markdown]
# ## DataFrame:
# ```
# mydataframe = DataFrame(lots of data...)
#         col1      col2        col3      age
# rows
# 0       'bruce'   'wayne'     'M'       42
# 1       'selina'  'kyle'      'F'       34
# 'two'   'kara'    'zor-el'    'F'       27
# 3       'clark'   'kent'      'M'       35
# ```
#
# **indexable**
#
# by either row(s) or column(s)
#
# `mydataframe['col1']`
#
# `mydataframe[['col1', 'age']]`

# %% [markdown]
# # Series
# ---

# %%
# Let's start by making a simple Series.
# It is customary to import pandas by the alias: pd

import pandas as pd
from pandas import Series

s = Series([33, 37, 27, 42])

# pandas will assign an index automatically starting at "0"

s
# Out:
# 0    33
# 1    37
# 2    27
# 3    42
# dtype: int64

# %%
# We can see that the object is a Series object

print(type(s))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# Series objects can be assigned a name 
# The index can also be assigned directly.

s.name = 'Justice League ages'
s.index = ['bruce', 'selina', 'kara', 'clark']

s
# Out:
# bruce     33
# selina    37
# kara      27
# clark     42
# Name: Justice League ages, dtype: int64

# %%
s['bruce']
# Out:
# 33

# %%
# The Series factory function allows you to assign attributes
#     such as the index directly.

s1 = Series([37, 36, 10, 36],
            index=['hal', 'victor', 'diana', 'billy'],
            name='More Justice League ages')
s1

# Generally, any ordered iterable can be used to produce the inputs
#     to a Series. We used a list here.
#     range(), generators, arrays, etc
# Out:
# billy     37
# victor    36
# diana     10
# billy     36
# Name: More Justice League ages, dtype: int64

# %%
# Accessing a row directly uses brackets and the 
#     name of the row.

s1['billy']
# Out:
# 36

# %%
# Accessing multiple rows uses the names of 
#     the rows embedded in a list

s1[   ['billy', 'victor', 'hal']     ]
# Out:
# billy     36
# victor    36
# hal       37
# Name: More Justice League ages, dtype: int64

# %%
# Accessing multiple rows may also use slice notation.
#     slice notation can often be used with both integer indexes and
#     string indexes.
#      

s1['hal':'diana']
# Out:
# hal       37
# victor    36
# diana     10
# Name: More Justice League ages, dtype: int64

# %%
# slice notation using integers still works even if we have 
#     applied a string-based index.

s1[0:3]
# Out:
# hal       37
# victor    36
# diana     10
# Name: More Justice League ages, dtype: int64

# %%
# Similarly, assignment of a value to a row
# uses bracket indexing

s1['diana'] = 32
s1
# Out:
# billy     37
# victor    36
# diana     32
# billy     36
# Name: More Justice League ages, dtype: int64

# %%
# Rows can be filtered using comparison operators
#     such as ==, <=, >=

s1[s1 == 32]

s1 > 35
# Out:
# billy      True
# victor     True
# diana     False
# billy      True
# Name: More Justice League ages, dtype: bool

# %% [markdown]
# # Experience Points!
# ---

# %% [markdown]
# In your **text editor** create a simple script called:
#
# ```bash
# my_series_01.py```
#
# Create a pandas Series called `restaurant_ratings` according to the following guidelines:
#
# * starting at the top, each row should contain one number from 1 to 5 (inclusive)
# * give the series a name called ratings
# * give the series an index with the names of five restaurants
#
# Execute your script in the **IPython interpreter** using the command:
#
# ```bash
# run my_series_01.py```
#
#
# From the IPython shell, explore your Series object by performing our typical explorations:
# * `type()`
# * `.<tab complete>`
#
# Also look at the attributes you have added:
#
# * `.name`
# * `.index`
#
# Lastly extract particular records from your Series:
#
# * Choose a record from the Series using the name of one of your restaurants
# * Choose three records from the Series using a list of names of restaurants

# %% [markdown]
# When you complete this exercise, please put your green post-it on your monitor.
#
# If you want to continue on at your own-pace, please feel free to do so.
#
# <img src='../images/green_sticky.300px.png' width='200' style='float:left'>

# %% [markdown]
# # Experience Points!
# ---

# %% [markdown]
# In your **text editor** create a simple script called:
#
# ```bash
# my_series_02.py```
#
# Create a pandas Series called `bacteria_lengths` according to the following guidelines:
#
# * starting at the top, each row should contain one number from 1 to 5000 (inclusive) incrementing by 100
# * give the series a name called length
# * Do not worry about an index for this series. Simply use the default indexing that Series provide.
#
# Execute your script from the **terminal/command line** using the command:
#
# ```bash
# ipython -i my_series_02.py```
#
#
# From the IPython Interpreter, explore your Series object by performing our typical explorations:
# * `type()`
# * `.<tab complete>`
#
# Also look at the attributes you have added or that were created by default:
#
# * `.name`
# * `.index`
#
# Lastly extract particular records from your Series:
#
# * Choose a record from the Series at index 23
# * Choose three records from the Series at index 23-27

# %% [markdown]
# When you complete this exercise, please put your green post-it on your monitor.
#
# If you want to continue on at your own-pace, please feel free to do so.
#
# <img src='../images/green_sticky.300px.png' width='200' style='float:left'>

# %%
# Much like numpy, pandas Series (and DataFrames)
#     offer vector mathematics whereby you can add to
#     or multiply against all rows or cells
#     WITHOUT using a for loop.

s1 * 2
# Out:
# billy     74
# victor    72
# diana     64
# billy     72
# Name: More Justice League ages, dtype: int64

# %%
s1
# Out:
# billy     37
# victor    36
# diana     32
# billy     36
# Name: More Justice League ages, dtype: int64

# %%
s1[['diana', 'billy']] * 20
# Out:
# diana    640
# billy    740
# billy    720
# Name: More Justice League ages, dtype: int64

# %%
s1
# Out:
# billy     37
# victor    36
# diana     32
# billy     36
# Name: More Justice League ages, dtype: int64

# %%
'diana' in s1

# %%
42 in [1, 2, 3, 4]
# Out:
# False

# %%
'lex' in s1
# Out:
# False

# %%
names = {'bruce wayne': 'bwayne@jleague.org',
         'hal jordan': 'hjordan@jleague.org',
         'clark kent': 'ckent@jleague.org',
         'barry allen': 'ballen@jleague.org',
         'diana prince': 'dprince@jleague.org',
         'arthur curry': 'acurry@jleague.org',
         'billy batson': 'bbatson@jleague.org',
         'john jones': 'jjones@jleague.org',
         'victor stone': 'vstone@jleague.org',
         'dick grayson': 'dgrayson@jleague.org',
         'ray palmer': 'rpalmer@jleague.org',
         'dinah lance': 'dlance@jleague.org',
         'kara zor-el': 'kzor-el@jleague.org',
         'john constantine': 'jconstantine@jleague.org',
         'barbara gordon': 'bgordon@jleague.org',
         'kyle rayner': 'krayner@jleague.org',
         'selina kyle': 'skyle@jleague.org',
         'wally west': 'wwest@jleague.org'
         }

emails = Series(names)
# emails.index
# emails.values

# %%
emails
# Out:
# arthur curry              acurry@jleague.org
# barbara gordon           bgordon@jleague.org
# barry allen               ballen@jleague.org
# billy batson             bbatson@jleague.org
# bruce wayne               bwayne@jleague.org
# clark kent                 ckent@jleague.org
# diana prince             dprince@jleague.org
# dick grayson            dgrayson@jleague.org
# dinah lance               dlance@jleague.org
# hal jordan               hjordan@jleague.org
# john constantine    jconstantine@jleague.org
# john jones                jjones@jleague.org
# kara zor-el              kzor-el@jleague.org
# kyle rayner              krayner@jleague.org
# ray palmer               rpalmer@jleague.org
# selina kyle                skyle@jleague.org
# victor stone              vstone@jleague.org
# wally west                 wwest@jleague.org
# dtype: object

# %%
emails[['barry allen', 'hal jordan', 'john jones']]
# Out:
# barry allen     ballen@jleague.org
# hal jordan     hjordan@jleague.org
# john jones      jjones@jleague.org
# dtype: object

# %% [markdown]
# # Analyzing data
# ---

# %%
s1 = Series(range(10, 16), index=['a', 'b', 'c', 'd', 'e', 'f'])
s2 = Series(range(16, 22), index=['a', 'b', 'c', 'x', 'y', 'z'])

# s1
# s2

# %%
s2
# Out:
# a    16
# b    17
# c    18
# x    19
# y    20
# z    21
# dtype: int64

# %%
s1
# Out:
# a    10
# b    11
# c    12
# d    13
# e    14
# f    15
# dtype: int64

# %%
s3 = s1 + s2
s1 + s2

# type(s3)
# pd.isnull(s3)
# s3.isnull()
# s3.<tab>
# Out:
# a    26.0
# b    28.0
# c    30.0
# d     NaN
# e     NaN
# f     NaN
# x     NaN
# y     NaN
# z     NaN
# dtype: float64

# %%
s3.isnull()
# Out:
# a    False
# b    False
# c    False
# d     True
# e     True
# f     True
# x     True
# y     True
# z     True
# dtype: bool

# %%
# How do I learn more?
# s3.<method_name>?        # just ask by typing the method name (sans parenthesis) and 
#                          # adding a question mark to see the builtin help docs
# 
# s3.value_counts?
# s3.value_counts(dropna=False)

# %%
s3.value_counts?

# %%
s3.dropna?
# s3

# %%
s4 = Series([42, 1, 1, 1, 2, 2, 3, 3, 3, 3, 3, 3, 4, 5, 6])

# s4.unique()
# s4.value_counts()
# s4.max()
# s4 + 2

# %%
s4.unique()
# Out:
# array([42,  1,  2,  3,  4,  5,  6])

# %%
def transmogrifier(x):
    '''hat tip to Calvin and Hobbes for introducing me to this 
    truly fantastic word. thanks, bill watterson.

    "transform, especially in a surprising or magical manner."
    '''
    new_val = '- ' + str(x ** 3) + ' -'
    return new_val

s4.apply(transmogrifier)
# Out:
# 0     - 74088 -
# 1         - 1 -
# 2         - 1 -
# 3         - 1 -
# 4         - 8 -
# 5         - 8 -
# 6        - 27 -
# 7        - 27 -
# 8        - 27 -
# 9        - 27 -
# 10       - 27 -
# 11       - 27 -
# 12       - 64 -
# 13      - 125 -
# 14      - 216 -
# dtype: object

# %% [markdown]
# # DataFrames
# ---

# %%
from pandas import DataFrame

# %%
# Making a DataFrame # 1
# Using a dictionary:

data = {'hero': ['billy', 'billy', 'billy', 'selina', 'selina'],
        'date': ['Jan 10', 'Jan 11', 'Jan 12', 'Jan 10', 'Jan 11'],
        'emails': [111, 121, 93, 211, 210]}

df = DataFrame(data)
df
# Out:
#      date  emails    hero
# 0  Jan 10     111   billy
# 1  Jan 11     121   billy
# 2  Jan 12      93   billy
# 3  Jan 10     211  selina
# 4  Jan 11     210  selina

# %%
df = DataFrame(data, columns=['date', 'hero', 'emails'])
df
# Out:
#      date    hero  emails
# 0  Jan 10   billy     111
# 1  Jan 11   billy     121
# 2  Jan 12   billy      93
# 3  Jan 10  selina     211
# 4  Jan 11  selina     210

# %%
df = DataFrame(data, columns=['date', 'hero', 'emails', 'instagrams'])

# df.index = [1, 2, 3, 4, 5]

# df
# df.columns

# %%
df['instagrams'] = 42

# %%
df
# Out:
#      date    hero  emails  instagrams
# 0  Jan 10   billy     111          42
# 1  Jan 11   billy     121          42
# 2  Jan 12   billy      93          42
# 3  Jan 10  selina     211          42
# 4  Jan 11  selina     210          42

# %%
df[['date', 'emails'    ] ]
# Out:
#      date  emails
# 0  Jan 10     111
# 1  Jan 11     121
# 2  Jan 12      93
# 3  Jan 10     211
# 4  Jan 11     210

# %%
# df['hero']
# df.hero

# df.loc[3]
df.loc[0:4:2]
# df.ix[3:5]
# df.ix[1:5:2]

# Deprecation warning... use df.loc and df.iloc instead
# Out:
#      date    hero  emails  instagrams
# 0  Jan 10   billy     111          42
# 2  Jan 12   billy      93          42
# 4  Jan 11  selina     210          42

# %%
from pandas import Series


df.instagrams = 50

# df['instragram']



ins = Series([10, 20, 30], index=[1, 3, 5])
ins
# Out:
# 1    10
# 3    20
# 5    30
# dtype: int64

# %%
df.instagrams
# Out:
# 0    50
# 1    50
# 2    50
# 3    50
# 4    50
# Name: instagrams, dtype: int64

# %%
df.instagrams = ins
df
# Out:
#      date    hero  emails  instagrams
# 0  Jan 10   billy     111         NaN
# 1  Jan 11   billy     121        10.0
# 2  Jan 12   billy      93         NaN
# 3  Jan 10  selina     211        20.0
# 4  Jan 11  selina     210         NaN

# %%
df
# Out:
#      date    hero  emails  instagrams
# 0  Jan 10   billy     111         NaN
# 1  Jan 11   billy     121        10.0
# 2  Jan 12   billy      93         NaN
# 3  Jan 10  selina     211        20.0
# 4  Jan 11  selina     210         NaN

# %%
# If you want to add a new column, dataframes are completely
#     mutable: columns can be added at will.

df['overworked'] = df['emails'] >= 120
df
# Out:
#      date    hero  emails  instagrams overworked
# 0  Jan 10   billy     111         NaN      False
# 1  Jan 11   billy     121        10.0       True
# 2  Jan 12   billy      93         NaN      False
# 3  Jan 10  selina     211        20.0       True
# 4  Jan 11  selina     210         NaN       True

# %%
df[    df.overworked == False       ]
# Out:
#      date   hero  emails  instagrams overworked
# 0  Jan 10  billy     111         NaN      False
# 2  Jan 12  billy      93         NaN      False

# %%
# If you want to add a new column, dataframes are completely
#     mutable: columns can be added at will.

standalone_series = df['emails'] >= 120
standalone_series
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4     True
# Name: emails, dtype: bool

# %%
standalone_series = df['instagrams'] != 10.0
standalone_series
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# Name: instagrams, dtype: bool

# %%
df[df.date != 'Jan 10']
# Out:
#      date    hero  emails  instagrams overworked
# 1  Jan 11   billy     121        10.0       True
# 2  Jan 12   billy      93         NaN      False
# 4  Jan 11  selina     210         NaN       True

# %%
# Making a DataFrame # 2
# Using a dictionary with nested dictionaries...

data = {'billy': {'Jan 10': 202, 'Jan 11': 220, 'Jan 12': 198},
        'selina': {'Jan 09': 246, 'Jan 10': 235, 'Jan 11': 243}}

# %%
df2 = DataFrame(data)
df2
# Out:
#         billy  selina
# Jan 09    NaN   246.0
# Jan 10  202.0   235.0
# Jan 11  220.0   243.0
# Jan 12  198.0     NaN

# %%
# df2.T
dft = df2.T
dft
# Out:
#         Jan 09  Jan 10  Jan 11  Jan 12
# billy      NaN   202.0   220.0   198.0
# selina   246.0   235.0   243.0     NaN

# %%
dft.columns.name = 'date'
dft.index.name = 'hero'

# %%
dft
# Out:
# date    Jan 09  Jan 10  Jan 11  Jan 12
# hero
# billy      NaN   202.0   220.0   198.0
# selina   246.0   235.0   243.0     NaN

# %%
# using indexes
nums = Series(range(10, 16),
              index=['t', 'u', 'v', 'x', 'y', 'z'])
nums
# Out:
# t    10
# u    11
# v    12
# x    13
# y    14
# z    15
# dtype: int64

# %%
i = nums.index
print(type(i), i)
# Out:
# <class 'pandas.indexes.base.Index'> Index(['t', 'u', 'v', 'x', 'y', 'z'], dtype='object')

# %%
i[::3]

# i[2:4]
# i[::2]
# i[::3]
# i[4]
# Out:
# Index(['t', 'x'], dtype='object')

# %%
logs = pd.read_csv('../15/log_file_1000.csv', names=['name',
                                                     'email',
                                                     'fm_ip',
                                                     'to_ip',
                                                     'date_time',
                                                     'lat',
                                                     'long',
                                                     'payload_size'])

# %%
logs
# Out:
# 975    60.15.193.250  2015-09-08T11:15:44  46.53470   7.94436        153158
# 976    102.86.56.213  2015-09-08T11:15:52  46.47032  11.22509        918654
# 977     60.15.193.95  2015-09-08T11:17:03  46.36607  10.96719        698773
# 978  106.152.115.161  2015-09-08T11:17:34  47.15281   8.41110        612255
# 979   106.152.115.49  2015-09-08T11:18:09  49.33927   9.51874        745248
# 980    155.130.121.6  2015-09-08T11:18:58  48.73055  11.95678         21740
# 981    102.86.56.199  2015-09-08T11:19:08  47.05942  12.39399        410269
# 982    102.86.56.203  2015-09-07T11:19:53  46.13889   8.64398        433466
# 983    190.214.22.59  2015-09-07T11:20:19  47.80468  10.42317          4553
# 984   169.28.228.152  2015-09-07T11:20:26  47.55302  12.28492        979864
# 985    106.152.114.9  2015-09-07T11:21:42  49.59466  12.35677          4763
# 986    106.152.114.9  2015-09-07T11:23:09  46.31633  10.80840        807268
# 987    220.211.18.12  2015-09-07T11:24:46  47.49435  11.57190        993459
# 988   75.122.132.124  2015-09-07T11:25:10  45.58382  10.53666        255782
# 989    155.130.121.6  2015-09-06T11:25:17  49.63044   8.06597        180883
# 990   190.214.22.201  2015-09-06T11:26:03  46.41245  11.76792         56427
# 991   169.28.228.153  2015-09-06T11:26:47  48.75553  10.89382        465874
# 992   169.28.228.153  2015-09-06T11:27:14  47.99365  10.60004        381008
# 993  106.152.115.161  2015-09-06T11:28:21  46.18375  10.50809         52774
# 994     60.15.193.95  2015-09-06T11:29:37  48.95031  12.15849        646359
# 995    60.15.193.249  2015-09-05T11:29:55  48.90180  12.26173        572009
# 996     60.15.193.95  2015-09-05T11:31:10  46.79957  11.39590        520973
# 997    75.122.133.10  2015-09-05T11:31:47  47.22726   8.13069        193138
# 998   169.28.228.152  2015-09-04T11:32:18  48.28877   9.67684        575482
# 999    106.152.114.9  2015-09-04T11:32:52  45.43995  11.83160         42810
#
# [1000 rows x 8 columns]

# %%
pd.read_csv?

# %%
logs.fm_ip.unique()

# %%
logs.name.value_counts()

# %%
logs.name.tail(13)
# Out:
# 987        dick grayson
# 988        dick grayson
# 989        arthur curry
# 990        arthur curry
# 991      barbara gordon
# 992    john constantine
# 993        arthur curry
# 994         selina kyle
# 995          clark kent
# 996        billy batson
# 997         bruce wayne
# 998          ray palmer
# 999         bruce wayne
# Name: name, dtype: object

# %%
g = logs.groupby(logs.fm_ip)
type(g)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
g.ngroups
# Out:
# 30

# %%
g.first()
# Out:
#                              name                     email            to_ip  \
# fm_ip
# 102.86.56.199        diana prince       dprince@jleague.org     60.15.193.74
# 102.86.56.203          hal jordan       hjordan@jleague.org    102.86.56.213
# 102.86.56.213          hal jordan       hjordan@jleague.org    102.86.56.213
# 102.86.56.243         bruce wayne        bwayne@jleague.org   106.152.115.49
# 106.152.114.248        ray palmer       rpalmer@jleague.org    102.86.56.203
# 106.152.114.9         barry allen        ballen@jleague.org    102.86.56.243
# 106.152.115.130      dick grayson      dgrayson@jleague.org    220.211.18.31
# 220.211.18.31    2016-02-05T21:52:27  49.73236  11.51376        390646
# 220.211.18.48    2016-02-07T21:49:26  48.85730   9.23887        421284
# 60.15.193.249    2016-02-04T21:59:41  49.55200  11.59746        567714
# 60.15.193.250    2016-02-08T21:46:53  47.11673  10.35874        856820
# 60.15.193.74     2016-02-07T21:48:04  48.59134  12.30683        171910
# 60.15.193.95     2016-02-07T21:49:02  48.20129  10.54183        916813
# 75.122.132.124   2016-02-05T21:57:39  47.30706   8.47864        212859
# 75.122.133.10    2016-01-28T22:38:05  47.17551   9.02421        478151
# 75.122.133.241   2016-01-28T22:36:44  47.71897  10.77419        901550
# 75.122.133.75    2016-02-01T22:09:44  46.68394  10.58863        182642

# %%
for item in g:
    print(item)

# %%
type(g.get_group('106.152.115.161'))
# Out:
# pandas.core.frame.DataFrame

# %%
g.get_group('106.152.115.161').head(10)
# Out:
#                date_time                     email       lat      long  \
# 1    2016-02-08T21:45:37        acurry@jleague.org  45.10327  11.68293
# 124  2016-01-18T23:26:50  jconstantine@jleague.org  46.51786   7.51440
# 137  2016-01-17T23:39:15        jjones@jleague.org  47.59412  11.93051
# 149  2016-01-14T23:48:04       bbatson@jleague.org  48.42538  10.99307
# 168  2016-01-12T00:05:46         ckent@jleague.org  47.15144   8.52435
# 173  2016-01-12T00:09:58        ballen@jleague.org  45.83844   8.21253
# 188  2016-01-11T00:22:31        acurry@jleague.org  48.32620   9.66367
# 201  2016-01-08T00:36:08       kzor-el@jleague.org  49.26437  12.09269
# 210  2016-01-06T00:43:44       bbatson@jleague.org  47.02258   7.75461
# 259  2015-12-31T01:24:57       bbatson@jleague.org  48.95450   9.75673
#
#                  name  payload_size            to_ip
# 1        arthur curry        249206  106.152.114.248
# 124  john constantine        197413   106.152.115.49
# 137        john jones        141543   75.122.132.124
# 149      billy batson        395075    75.122.133.10
# 168        clark kent        924131  106.152.115.130
# 173       barry allen        621909    60.15.193.249
# 188      arthur curry         15034    75.122.133.75
# 201       kara zor-el        760026   75.122.133.241
# 210      billy batson        389068    190.214.22.94
# 259      billy batson        503714   75.122.132.124

# %%
def date_only(dt):
    day = dt.split('T')[0]
    return day

# %%
logs['date'] = logs.date_time.apply(date_only)

# %%
logs.columns

# %%
logs.date
# Out:
# 0      2016-02-08
# 1      2016-02-08
# 2      2016-02-08
# 3      2016-02-07
# 4      2016-02-07
# 5      2016-02-07
# 6      2016-02-07
# 7      2016-02-07
# 8      2016-02-06
# 9      2016-02-06
# 10     2016-02-05
# 11     2016-02-05
# 12     2016-02-05
# 13     2016-02-05
# 14     2016-02-05
# 15     2016-02-05
# 16     2016-02-05
# 17     2016-02-05
# 18     2016-02-05
# 19     2016-02-04
# 20     2016-02-04
# 21     2016-02-03
# 22     2016-02-03
# 23     2016-02-03
# 24     2016-02-02
# 25     2016-02-02
# 26     2016-02-02
# 27     2016-02-02
# 28     2016-02-01
# 29     2016-02-01
#           ...
# 970    2015-09-09
# 971    2015-09-09
# 972    2015-09-09
# 973    2015-09-08
# 974    2015-09-08
# 975    2015-09-08
# 976    2015-09-08
# 977    2015-09-08
# 978    2015-09-08
# 979    2015-09-08
# 980    2015-09-08
# 981    2015-09-08
# 982    2015-09-07
# 983    2015-09-07
# 984    2015-09-07
# 985    2015-09-07
# 986    2015-09-07
# 987    2015-09-07
# 988    2015-09-07
# 989    2015-09-06
# 990    2015-09-06
# 991    2015-09-06
# 992    2015-09-06
# 993    2015-09-06
# 994    2015-09-06
# 995    2015-09-05
# 996    2015-09-05
# 997    2015-09-05
# 998    2015-09-04
# 999    2015-09-04
# Name: date, dtype: object

# %%
tf = logs.fm_ip == logs.to_ip

# %%
tf
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# 979    False
# 980    False
# 981    False
# 982    False
# 983    False
# 984    False
# 985    False
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# 991    False
# 992    False
# 993    False
# 994     True
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# dtype: bool

# %%
tf.unique()

# %%
tf.value_counts()
# Out:
# False    967
# True      33
# dtype: int64

# %%
logs[['fm_ip', 'to_ip']].head(12)
# Out:
#               fm_ip            to_ip
# 0   155.130.121.215   75.122.133.241
# 1   106.152.115.161  106.152.114.248
# 2     60.15.193.250  155.130.121.215
# 3    190.214.22.201   190.214.22.116
# 4      60.15.193.74     60.15.193.95
# 5   106.152.114.248    102.86.56.203
# 6      60.15.193.95  155.130.121.215
# 7     220.211.18.48   106.152.115.49
# 8   106.152.114.248   190.214.22.201
# 9      60.15.193.74  106.152.114.248
# 10    220.211.18.31    190.214.22.94
# 11   190.214.22.116   190.214.22.116

# %%
logs = pd.read_csv('../15/log_file_na.csv', names=['name',
                                                     'email',
                                                     'fm_ip',
                                                     'to_ip',
                                                     'date_time',
                                                     'lat',
                                                     'long',
                                                     'payload_size'])

# %%
logs
# Out:
#                  name                     email            fm_ip  \
# 0          hal jordan       hjordan@jleague.org  134.218.213.165
# 1          wally west         wwest@jleague.org  134.218.213.202
# 2        dick grayson      dgrayson@jleague.org    50.133.32.218
# 3        dick grayson      dgrayson@jleague.org    50.133.32.231
# 4          wally west         wwest@jleague.org  240.237.148.218
# 5          ray palmer       rpalmer@jleague.org      103.11.11.6
# 6         dinah lance        dlance@jleague.org  134.218.213.176
# 7          ray palmer       rpalmer@jleague.org      103.11.11.6
# 8        arthur curry        acurry@jleague.org  134.218.213.136
# 9          ray palmer       rpalmer@jleague.org  146.157.216.247
# 10        barry allen        ballen@jleague.org  253.253.228.221
# 11        kyle rayner       krayner@jleague.org  146.157.216.209
# 12         wally west         wwest@jleague.org  240.237.148.218
# 13       billy batson       bbatson@jleague.org   240.237.148.67
# 14        bruce wayne        bwayne@jleague.org  146.157.217.205
# 984  253.253.228.165  2015-08-15T11:39:35  47.16971   8.49307       37166.0
# 985   253.253.228.10  2015-08-15T11:40:06  47.63950  11.32197      515960.0
# 986  146.157.217.205  2015-08-14T11:40:30  47.08782  10.91131      365041.0
# 987    50.133.32.252  2015-08-14T11:41:36  45.73610   8.37914      215171.0
# 988  240.237.148.218  2015-08-14T11:42:21  49.76455   9.69227      645071.0
# 989  134.218.213.165  2015-08-13T11:42:59  48.74267   8.87721      697997.0
# 990  134.218.213.184  2015-08-13T11:43:24  47.39125   9.48230      476157.0
# 991  134.218.213.184  2015-08-13T11:44:35  47.97750  12.32473      482869.0
# 992  134.218.213.202  2015-08-13T11:45:31  49.26697  11.03992      493177.0
# 993    50.133.32.218  2015-08-12T11:46:46  48.56864   9.28633      976436.0
# 994   146.157.216.74  2015-08-12T11:46:50  46.82528   8.80083      984331.0
# 995    50.133.32.217  2015-08-12T11:47:04  49.15164   8.84625      449577.0
# 996     8.79.169.212  2015-08-12T11:48:09  48.28602  11.15193      865382.0
# 997    50.133.32.231  2015-08-12T11:49:23  49.03042  10.59940      978648.0
# 998   253.253.228.26  2015-08-12T11:50:53  48.23459  10.23250       14429.0
# 999     103.11.11.14  2015-08-12T11:50:55  45.05278  10.99765      974077.0
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Experience Points!
# ---

# %% [markdown]
# In your **text editor** create a simple script called:
#
# ```bash
# my_DataFrame_01.py
# ```
#
# Follow these steps:
#
# 1. Create a pandas `DataFrame` called `na_log` by reading in the csv `log_file_na.csv` and using the names:
#
#     ```['name', 'email', 'fm_ip', 'to_ip', 'date_time', 'lat', 'long', 'payload_size']```
# 1. Get the `payload_size` column and select it and label it as a separate pandas `Series`
# 1. Run both the `min()` method and the `max()` method on your `Series`
# 1. Calculate the difference between the two values you get back
#
# Execute your script from the **terminal/command line** using the command:
#
# ```bash
# ipython -i my_DataFrame_01.py
# ```

# %% [markdown]
# When you complete this exercise, please put your green post-it on your monitor.
#
# If you want to continue on at your own-pace, please feel free to do so.
#
# <img src='../images/green_sticky.300px.png' width='200' style='float:left'>

# %% [markdown]
# # Experience Points!
# ---

# %% [markdown]
# In your **text editor** create a simple script called:
#
# ```bash
# my_DataFrame_02.py
# ```
#
# Then do the following
#
# 1. Create a pandas dataFrame called `na_log` by reading in the csv `log_file_na.csv` and using the names:
#     1. `['name', 'email', 'fm_ip', 'to_ip', 'date_time', 'lat', 'long', 'payload_size']`
# 1. Print to the screen the content of the two columns: `long` and `lat`
# 1. Create a new Series that is made up of the **difference** between the value of `long` and the value of `lat`
# 1. Apply the `round()` function to the Series so that each value is rounded to the nearest full integer
# 1. Use the `.unique()` method to print out all of the unique values
#
# Execute your script from the **terminal/command line** using the command:
#
# ```bash
# ipython -i my_DataFrame_02.py
# ```

# %% [markdown]
# When you complete this exercise, please put your green post-it on your monitor.
#
# If you want to continue on at your own-pace, please feel free to do so.
#
# <img src='../images/green_sticky.300px.png' width='200' style='float:left'>

# %%
(logs.lat - logs.long).apply(round).value_counts()
